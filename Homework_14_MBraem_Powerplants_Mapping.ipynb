# %% [markdown]
# # The Powerplants in the USA

# %% [markdown]
# Part 1 – Mapping

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import numpy as np
# %matplotlib inline

# %%
states = gpd.read_file("cb_2016_us_state_500k/cb_2016_us_state_500k.shp")
states.plot()

# %%
powerplants = pd.read_csv('pm25_annual_fixed.csv')
powerplants.head(3)
# Out:
#    State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0           1            3        10           88101    1  30.497478
# 1           1           27         1           88101    1  33.284928
# 2           1           33      1002           88101    1  34.762619
#
#    Longitude  Datum            Parameter Name Sample Duration  \
# 0 -87.880258  NAD83  PM2.5 - Local Conditions         24 HOUR
# 1 -85.803608  NAD83  PM2.5 - Local Conditions         24 HOUR
# 2 -87.638097  NAD83  PM2.5 - Local Conditions         24 HOUR
#
#           ...          75th Percentile 50th Percentile 10th Percentile  \
# 0         ...                      8.0             5.7             3.8
# 1         ...                     12.4             8.7             2.9
# 2         ...                     10.0             7.1             3.5
#
#      Local Site Name                                            Address  \
# 0  FAIRHOPE, Alabama  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...
# ...

# %%
powerplants.shape
# Out:
# (441, 55)

# %%
powerplants.dtypes
# Out:
# State Code                         int64
# County Code                        int64
# Site Num                           int64
# Parameter Code                     int64
# POC                                int64
# Latitude                         float64
# Longitude                        float64
# Datum                             object
# Parameter Name                    object
# Sample Duration                   object
# Pollutant Standard                object
# Metric Used                       object
# Method Name                       object
# Year                               int64
# Units of Measure                  object
# Event Type                        object
# Observation Count                  int64
# Observation Percent                int64
# Completeness Indicator            object
# Valid Day Count                    int64
# Required Day Count                 int64
# Exceptional Data Count             int64
# Null Data Count                    int64
# ...

# %%
points = df.apply(lambda row: Point(row.Longitude, row.Latitude), axis=1)
powerplants = gpd.GeoDataFrame(powerplants, geometry=points)
powerplants.plot()

# %%
ax = states.plot(figsize=(40,40), color='#BBBBBB', linewidth=0.25, edgecolor='white')
powerplants.plot(ax=ax, color='black', markeredgewidth=0, markersize=2, alpha=0.5)
ax.axis('off')
# Out:
# (-197.09527795, 197.72483894999999, -18.84439205, 75.660855049999995)

# %%
#for detail zoom
ax = states.plot(figsize=(40,40), color='#BBBBBB', linewidth=0.25, edgecolor='white')
powerplants.plot(ax=ax, color='black', markeredgewidth=0, markersize=2, alpha=0.5)

# %%
ax = states.plot(figsize=(20,20), color='#BBBBBB', linewidth=0.25, edgecolor='white')
powerplants.plot(ax=ax, color='blue', markeredgewidth=0, markersize=5, alpha=.5)
ax.axis('off')
ax.set_xlim([-130, -60])
ax.set_ylim([20, 50])
# Out:
# (20, 50)

# %%
powerplants.sort_values(by='Method Name')['Method Name']
# Out:
# 322    Andersen RAAS2.5-300 PM2.5 SEQ w/WINS - GRAVIM...
# 266    BGI Models PQ200-VSCC or PQ200A-VSCC - Gravime...
# 302    BGI Models PQ200-VSCC or PQ200A-VSCC - Gravime...
# 300    BGI Models PQ200-VSCC or PQ200A-VSCC - Gravime...
# 124    BGI Models PQ200-VSCC or PQ200A-VSCC - Gravime...
# 299    BGI Models PQ200-VSCC or PQ200A-VSCC - Gravime...
# 328    BGI Models PQ200-VSCC or PQ200A-VSCC - Gravime...
# 321    BGI Models PQ200-VSCC or PQ200A-VSCC - Gravime...
# 329    BGI Models PQ200-VSCC or PQ200A-VSCC - Gravime...
# 118    BGI Models PQ200-VSCC or PQ200A-VSCC - Gravime...
# 117    BGI Models PQ200-VSCC or PQ200A-VSCC - Gravime...
# 296    BGI Models PQ200-VSCC or PQ200A-VSCC - Gravime...
# 335    BGI Models PQ200-VSCC or PQ200A-VSCC - Gravime...
# 336    BGI Models PQ200-VSCC or PQ200A-VSCC - Gravime...
# 339    BGI Models PQ200-VSCC or PQ200A-VSCC - Gravime...
# 297    BGI Models PQ200-VSCC or PQ200A-VSCC - Gravime...
# ...
