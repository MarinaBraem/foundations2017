# %% [markdown]
# # Scraping: H&M Sales
#
# **It's officially hot outside**, which means we need some summertime clothes. We live in New York City, though, so all our money goes to rent: we need to shop *as cheaply as possible*. So let's shop [sales at H&M](http://www.hm.com/us/products/sale)!
#
# **Answer the questions below using either Men's or Women's sale items at H&M.**
#
# ## Preparation: knowing your tags
#
# ### What is the tag name and class name for a product?

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "http://api.hm.com/v2/us/en/products/display?categories=sale&concealCategories=true&pageSize=60&page=1&deviceType=DESKTOP"
response = requests.get(url)
data = response.json()
articles = data['displayArticles']
articles
# Out:
# [{'activityArticleNumber': '721398',
#   'additionalImages': [],
#   'articleCode': '60133-B',
#   'assortmentState': 'CURRENT',
#   'availableSizeInfo': [{'sizeName': 'XS', 'stockSize': '003'},
#    {'sizeName': 'S', 'stockSize': '004'},
#    {'sizeName': 'M', 'stockSize': '005'},
#    {'sizeName': 'L', 'stockSize': '006'}],
#   'availableSwatches': [{'articleCode': '60133-B',
#     'castorArticleId': '0458058004',
#     'colour': '012b40',
#     'fabricImageResource': '/fabric/2017/456C0474-E1A7-409D-B28D-8DCF9EA8337D.jpg',
#     'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2017/456C0474-E1A7-409D-B28D-8DCF9EA8337D.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#   'castorArticleNumber': '004',
#   'castorProductNumber': '0458058',
#   'colourDescription': 'Turquoise',
#   'departments': [{'code': 'LADIES',
#     'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#     'paths': ['LADIES/LADIES_TOPS/LADIES_TOPS_SHORT_SLEEVED',
#      'LADIES/LADIES_BASICS/LADIES_BASICS_TOPS/LADIES_BASICS_TOPS_SHORTSLEEVE']}],
#   'name': 'Jersey Top',
#   'priceInfo': {'currencyIso': 'USD',
#    'currencySymbol': '$',
#    'formattedOldPrice': '$12.99',
#    'formattedPrice': '$5',
#    'onSale': True,
#    'prefixCurrencySymbol': '$',
#    'price': 5.0,
#    'suffixCurrencySymbol': ''},
#   'primaryImage': {'type': 'STILL_LIFE_FRONT',
#    'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2017/E00 0458058 004 89 3203.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[1]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#   'productNumber': '60133',
#   'stockState': 'IN_STOCK',
#   'textualMarkers': [],
#   'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs2MDEzMy01X2VuX1VTOzYwMTMzLUJfZW5fVVM7O05PTkU6Tk9ORTs1OTs'},
#   'webUrl': 'http://www.hm.com/us/product/60133?article=60133-B'},
#  {'activityArticleNumber': '525038',
#   'additionalImages': [],
#   'articleCode': '60133-F',
#   'assortmentState': 'CURRENT',
#   'availableSizeInfo': [{'sizeName': 'XS', 'stockSize': '003'},
#    {'sizeName': 'S', 'stockSize': '004'},
#    {'sizeName': 'M', 'stockSize': '005'},
#    {'sizeName': 'L', 'stockSize': '006'}],
#   'availableSwatches': [{'articleCode': '60133-F',
#     'castorArticleId': '0458058008',
#     'colour': 'f69eb7',
#     'fabricImageResource': '/fabric/2016/BE6AFADA-1871-417D-9821-7103F37463B7.jpg',
#     'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2016/BE6AFADA-1871-417D-9821-7103F37463B7.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#   'castorArticleNumber': '008',
#   'castorProductNumber': '0458058',
#   'colourDescription': 'Light pink melange',
#   'departments': [{'code': 'LADIES',
#     'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#     'paths': ['LADIES/LADIES_TOPS/LADIES_TOPS_SHORT_SLEEVED',
#      'LADIES/LADIES_BASICS/LADIES_BASICS_TOPS/LADIES_BASICS_TOPS_SHORTSLEEVE']}],
#   'name': 'Jersey Top',
#   'priceInfo': {'currencyIso': 'USD',
#    'currencySymbol': '$',
#    'formattedOldPrice': '$12.99',
#    'formattedPrice': '$5',
#    'onSale': True,
#    'prefixCurrencySymbol': '$',
#    'price': 5.0,
#    'suffixCurrencySymbol': ''},
#   'primaryImage': {'type': 'STILL_LIFE_FRONT',
#    'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2016/E00 0458058 008 25 1076.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[1]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#   'productNumber': '60133',
#   'stockState': 'IN_STOCK',
#   'textualMarkers': [],
#   'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs2MDEzMy0yX2VuX1VTOzYwMTMzLUZfZW5fVVM7O05PTkU6Tk9ORTs1OTs'},
#   'webUrl': 'http://www.hm.com/us/product/60133?article=60133-F'},
#  {'activityArticleNumber': '041829',
#   'additionalImages': [],
#   'articleCode': '60133-E',
#   'assortmentState': 'CURRENT',
#   'availableSizeInfo': [{'sizeName': 'XS', 'stockSize': '003'},
#    {'sizeName': 'S', 'stockSize': '004'},
#    {'sizeName': 'M', 'stockSize': '005'},
#    {'sizeName': 'L', 'stockSize': '006'}],
#   'availableSwatches': [{'articleCode': '60133-E',
#     'castorArticleId': '0458058005',
#     'colour': '000000',
#     'fabricImageResource': '/fabric/2016/3D493D1F-213C-4CC1-96E4-E6D7D2E3FD75.jpg',
#     'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2016/3D493D1F-213C-4CC1-96E4-E6D7D2E3FD75.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#   'castorArticleNumber': '005',
#   'castorProductNumber': '0458058',
#   'colourDescription': 'Black',
#   'departments': [{'code': 'LADIES',
#     'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#     'paths': ['LADIES/LADIES_TOPS/LADIES_TOPS_SHORT_SLEEVED',
#      'LADIES/LADIES_BASICS/LADIES_BASICS_TOPS/LADIES_BASICS_TOPS_SHORTSLEEVE']}],
#   'name': 'Jersey Top',
#   'priceInfo': {'currencyIso': 'USD',
#    'currencySymbol': '$',
#    'formattedOldPrice': '$12.99',
#    'formattedPrice': '$5',
#    'onSale': True,
#    'prefixCurrencySymbol': '$',
#    'price': 5.0,
#    'suffixCurrencySymbol': ''},
#   'primaryImage': {'type': 'STILL_LIFE_FRONT',
#    'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2016/E00 0458058 005 25 1075.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[1]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#   'productNumber': '60133',
#   'stockState': 'IN_STOCK',
#   'textualMarkers': [],
#   'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs2MDEzMy0xX2VuX1VTOzYwMTMzLUVfZW5fVVM7O05PTkU6Tk9ORTs1OTs'},
#   'webUrl': 'http://www.hm.com/us/product/60133?article=60133-E'},
#  {'activityArticleNumber': '739672',
#   'additionalImages': [],
#   'articleCode': '58550-I',
#   'assortmentState': 'CURRENT',
#   'availableSizeInfo': [{'sizeName': '2', 'stockSize': '032'},
#    {'sizeName': '4', 'stockSize': '034'},
#    {'sizeName': '6', 'stockSize': '036'},
#    {'sizeName': '8', 'stockSize': '038'},
#    {'sizeName': '10', 'stockSize': '040'},
#    {'sizeName': '12', 'stockSize': '042'},
#    {'sizeName': '14', 'stockSize': '044'},
#    {'sizeName': '16', 'stockSize': '046'},
#    {'sizeName': '18', 'stockSize': '048'},
#    {'sizeName': '20', 'stockSize': '050'}],
#   'availableSwatches': [{'articleCode': '58550-I',
#     'castorArticleId': '0434429024',
#     'colour': 'ffffff',
#     'fabricImageResource': '/fabric/2016/BF18D56D-8AC4-47F2-8327-8E3C3A6870E7.jpg',
#     'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2016/BF18D56D-8AC4-47F2-8327-8E3C3A6870E7.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#   'castorArticleNumber': '024',
#   'castorProductNumber': '0434429',
#   'colourDescription': 'White',
#   'departments': [{'code': 'LADIES',
#     'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#     'paths': ['LADIES/LADIES_EVERYDAY_FASHION/LADIES_EVERYDAY_FASHION_TROUSERS_JEANS',
#      'LADIES/LADIES_TROUSERS/LADIES_TROUSERS_SLIM']}],
#   'name': 'Super-slim-fit Pants',
#   'priceInfo': {'currencyIso': 'USD',
#    'currencySymbol': '$',
#    'formattedOldPrice': '$19.99',
#    'formattedPrice': '$9.99',
#    'onSale': True,
#    'prefixCurrencySymbol': '$',
#    'price': 9.99,
#    'suffixCurrencySymbol': ''},
#   'primaryImage': {'type': 'STILL_LIFE_FRONT',
#    'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2016/E00 0434429 024 32 1253.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[4]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#   'productNumber': '58550',
#   'stockState': 'IN_STOCK',
#   'textualMarkers': [],
#   'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs1ODU1MC00X2VuX1VTOzU4NTUwLUlfZW5fVVM7O05PTkU6Tk9ORTs1OTs'},
#   'webUrl': 'http://www.hm.com/us/product/58550?article=58550-I'},
#  {'activityArticleNumber': '573246',
#   'additionalImages': [],
#   'articleCode': '66751-C',
#   'assortmentState': 'CURRENT',
#   'availableSizeInfo': [{'sizeName': 'XS', 'stockSize': '003'},
#    {'sizeName': 'S', 'stockSize': '004'},
#    {'sizeName': 'M', 'stockSize': '005'},
#    {'sizeName': 'L', 'stockSize': '006'}],
#   'availableSwatches': [{'articleCode': '66751-C',
#     'castorArticleId': '0459230008',
#     'colour': '3c3837',
#     'fabricImageResource': '/fabric/2017/093D757B-AF6B-4A60-947A-03AFC6A18D1A.jpg',
#     'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2017/093D757B-AF6B-4A60-947A-03AFC6A18D1A.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#   'castorArticleNumber': '008',
#   'castorProductNumber': '0459230',
#   'colourDescription': 'Dark gray/Mickey Mouse',
#   'departments': [{'code': 'LADIES',
#     'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#     'paths': ['LADIES/LADIES_NIGHTWEAR/LADIES_NIGHTWEAR_PYJAMAS']}],
#   'name': 'Pajama Tank Top and Shorts',
#   'priceInfo': {'currencyIso': 'USD',
#    'currencySymbol': '$',
#    'formattedOldPrice': '$14.99',
#    'formattedPrice': '$7.99',
#    'onSale': True,
#    'prefixCurrencySymbol': '$',
#    'price': 7.99,
#    'suffixCurrencySymbol': ''},
#   'primaryImage': {'type': 'STILL_LIFE_FRONT',
#    'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2017/E00 0459230 008 00 2299.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[0]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#   'productNumber': '66751',
#   'stockState': 'IN_STOCK',
#   'textualMarkers': [],
#   'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs2Njc1MS0zLTAtMTFfZW5fVVM7NjY3NTEtQ19lbl9VUzs7Tk9ORTpOT05FOzU5Ow'},
#   'webUrl': 'http://www.hm.com/us/product/66751?article=66751-C'},
#  {'activityArticleNumber': '352079',
#   'additionalImages': [],
#   'articleCode': '58550-J',
#   'assortmentState': 'CURRENT',
#   'availableSizeInfo': [{'sizeName': '2', 'stockSize': '032'},
#    {'sizeName': '4', 'stockSize': '034'},
#    {'sizeName': '6', 'stockSize': '036'},
#    {'sizeName': '8', 'stockSize': '038'},
#    {'sizeName': '10', 'stockSize': '040'},
#    {'sizeName': '12', 'stockSize': '042'},
#    {'sizeName': '14', 'stockSize': '044'},
#    {'sizeName': '16', 'stockSize': '046'},
#    {'sizeName': '18', 'stockSize': '048'},
#    {'sizeName': '20', 'stockSize': '050'}],
#   'availableSwatches': [{'articleCode': '58550-F',
#     'castorArticleId': '0434429017',
#     'colour': '161e80',
#     'fabricImageResource': '/fabric/2016/A55E1A83-B8C6-4A00-B1A8-AD3DE8114DCB.jpg',
#     'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2016/A55E1A83-B8C6-4A00-B1A8-AD3DE8114DCB.jpg]&call=url[file:/mobile/v1/fabric/sprite]'},
#    {'articleCode': '58550-J',
#     'castorArticleId': '0434429016',
#     'colour': '9ba0e7',
#     'fabricImageResource': '/fabric/2017/A2598404-D177-48D5-BEC6-A1C923E9B93F.jpg',
#     'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2017/A2598404-D177-48D5-BEC6-A1C923E9B93F.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#   'castorArticleNumber': '016',
#   'castorProductNumber': '0434429',
#   'colourDescription': 'Light denim blue',
#   'departments': [{'code': 'LADIES',
#     'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#     'paths': ['LADIES/LADIES_EVERYDAY_FASHION/LADIES_EVERYDAY_FASHION_TROUSERS_JEANS',
#      'LADIES/LADIES_TROUSERS/LADIES_TROUSERS_SLIM']}],
#   'name': 'Super-slim-fit Pants',
#   'priceInfo': {'currencyIso': 'USD',
#    'currencySymbol': '$',
#    'formattedOldPrice': '$19.99',
#    'formattedPrice': '$9.99',
#    'onSale': True,
#    'prefixCurrencySymbol': '$',
#    'price': 9.99,
#    'suffixCurrencySymbol': ''},
#   'primaryImage': {'type': 'STILL_LIFE_FRONT',
#    'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2017/E00 0434429 016 14 1800.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[2]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#   'productNumber': '58550',
#   'stockState': 'IN_STOCK',
#   'textualMarkers': [],
#   'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs1ODU1MC0yX2VuX1VTOzU4NTUwLUpfZW5fVVM7O05PTkU6Tk9ORTs1OTs'},
#   'webUrl': 'http://www.hm.com/us/product/58550?article=58550-J'},
#  {'activityArticleNumber': '750994',
#   'additionalImages': [],
#   'articleCode': '65743-D',
#   'assortmentState': 'CURRENT',
#   'availableSizeInfo': [{'sizeName': 'XS', 'stockSize': '003'},
#    {'sizeName': 'S', 'stockSize': '004'},
#    {'sizeName': 'M', 'stockSize': '005'},
#    {'sizeName': 'L', 'stockSize': '006'},
#    {'sizeName': 'XL', 'stockSize': '007'},
#    {'sizeName': 'XXL', 'stockSize': '008'}],
#   'availableSwatches': [{'articleCode': '65743-D',
#     'castorArticleId': '0451456001',
#     'colour': 'abc0ef',
#     'fabricImageResource': '/fabric/2017/7232AAAF-1C35-4CA5-B671-B87C82B71B04.jpg',
#     'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2017/7232AAAF-1C35-4CA5-B671-B87C82B71B04.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#   'castorArticleNumber': '001',
#   'castorProductNumber': '0451456',
#   'colourDescription': 'Denim blue',
#   'departments': [{'code': 'MEN',
#     'name': 'NAVIGATION.LABEL.DEPARTMENT.MEN',
#     'paths': ['MEN/MEN_HM_MAN/MEN_HM_MAN_SHIRTS',
#      'MEN/MEN_SHIRTS/MEN_SHIRTS_CASUAL']}],
#   'name': 'Short-sleeved Shirt Slim fit',
#   'priceInfo': {'currencyIso': 'USD',
#    'currencySymbol': '$',
#    'formattedOldPrice': '$17.99',
#    'formattedPrice': '$7.99',
#    'onSale': True,
#    'prefixCurrencySymbol': '$',
#    'price': 7.99,
#    'suffixCurrencySymbol': ''},
#   'primaryImage': {'type': 'STILL_LIFE_FRONT',
#    'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2017/E00 0451456 001 64 0056.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[1]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#   'productNumber': '65743',
#   'stockState': 'IN_STOCK',
#   'textualMarkers': [{'markerDescription': '',
#     'markerText': 'Online Exclusive',
#     'markerType': 'ONLINE_EXCLUSIVE'}],
#   'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs2NTc0My00X2VuX1VTOzY1NzQzLURfZW5fVVM7O05PTkU6Tk9ORTs1OTs'},
#   'webUrl': 'http://www.hm.com/us/product/65743?article=65743-D'},
#  {'activityArticleNumber': '526180',
#   'additionalImages': [],
#   'articleCode': '65743-A',
#   'assortmentState': 'CURRENT',
#   'availableSizeInfo': [{'sizeName': 'XS', 'stockSize': '003'},
#    {'sizeName': 'S', 'stockSize': '004'},
#    {'sizeName': 'M', 'stockSize': '005'},
#    {'sizeName': 'L', 'stockSize': '006'},
#    {'sizeName': 'XL', 'stockSize': '007'},
#    {'sizeName': 'XXL', 'stockSize': '008'}],
#   'availableSwatches': [{'articleCode': '65743-A',
#     'castorArticleId': '0451456002',
#     'colour': '020f41',
#     'fabricImageResource': '/fabric/2017/5856055A-C8A9-4877-86C6-2EC86223B5AF.jpg',
#     'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2017/5856055A-C8A9-4877-86C6-2EC86223B5AF.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#   'castorArticleNumber': '002',
#   'castorProductNumber': '0451456',
#   'colourDescription': 'Dark denim blue',
#   'departments': [{'code': 'MEN',
#     'name': 'NAVIGATION.LABEL.DEPARTMENT.MEN',
#     'paths': ['MEN/MEN_HM_MAN/MEN_HM_MAN_SHIRTS',
#      'MEN/MEN_SHIRTS/MEN_SHIRTS_CASUAL']}],
#   'name': 'Short-sleeved Shirt Slim fit',
#   'priceInfo': {'currencyIso': 'USD',
#    'currencySymbol': '$',
#    'formattedOldPrice': '$17.99',
#    'formattedPrice': '$7.99',
#    'onSale': True,
#    'prefixCurrencySymbol': '$',
#    'price': 7.99,
#    'suffixCurrencySymbol': ''},
#   'primaryImage': {'type': 'STILL_LIFE_FRONT',
#    'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2017/E00 0451456 002 98 2020.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[1]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#   'productNumber': '65743',
#   'stockState': 'IN_STOCK',
#   'textualMarkers': [{'markerDescription': '',
#     'markerText': 'Online Exclusive',
#     'markerType': 'ONLINE_EXCLUSIVE'}],
#   'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs2NTc0My01X2VuX1VTOzY1NzQzLUFfZW5fVVM7O05PTkU6Tk9ORTs1OTs'},
#   'webUrl': 'http://www.hm.com/us/product/65743?article=65743-A'},
#  {'activityArticleNumber': '340593',
#   'additionalImages': [],
#   'articleCode': '66190-C',
#   'assortmentState': 'CURRENT',
#   'availableSizeInfo': [{'sizeName': '2', 'stockSize': '032'},
#    {'sizeName': '4', 'stockSize': '034'},
#    {'sizeName': '6', 'stockSize': '036'},
#    {'sizeName': '8', 'stockSize': '038'},
#    {'sizeName': '10', 'stockSize': '040'},
#    {'sizeName': '12', 'stockSize': '042'},
#    {'sizeName': '16', 'stockSize': '046'},
#    {'sizeName': '18', 'stockSize': '048'},
#    {'sizeName': '20', 'stockSize': '050'}],
#   'availableSwatches': [{'articleCode': '66190-C',
#     'castorArticleId': '0495206003',
#     'colour': '5b3d25',
#     'fabricImageResource': '/fabric/2017/6E38ADE6-2F1B-4DBF-9B69-58027548E31D.jpg',
#     'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2017/6E38ADE6-2F1B-4DBF-9B69-58027548E31D.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#   'castorArticleNumber': '003',
#   'castorProductNumber': '0495206',
#   'colourDescription': 'Khaki green',
#   'departments': [{'code': 'LADIES',
#     'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#     'paths': ['LADIES/LADIES_JACKETS_COATS/LADIES_JACKETS_COATS_JACKETS',
#      'LADIES/LADIES_EVERYDAY_FASHION/LADIES_EVERYDAY_FASHION_JACKETS_COATS/LADIES_EVERYDAY_FASHION_JACKETS_COATS_JACKETS',
#      'LADIES/LADIES_SELECTED/LADIES_SELECTED_CONSCIOUS-SUSTAINABLE-STYLE']}],
#   'name': 'Lyocell Jacket',
#   'priceInfo': {'currencyIso': 'USD',
#    'currencySymbol': '$',
#    'formattedOldPrice': '$49.99',
#    'formattedPrice': '$19.99',
#    'onSale': True,
#    'prefixCurrencySymbol': '$',
#    'price': 19.99,
#    'suffixCurrencySymbol': ''},
#   'primaryImage': {'type': 'STILL_LIFE_FRONT',
#    'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2017/E00 0495206 003 66 2172.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[2]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#   'productMarker': {'markerDescription': '',
#    'markerText': 'CONSCIOUS',
#    'markerType': 'CONSCIOUS'},
#   'productNumber': '66190',
#   'stockState': 'IN_STOCK',
#   'textualMarkers': [],
#   'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs2NjE5MC01X2VuX1VTOzY2MTkwLUNfZW5fVVM7O05PTkU6Tk9ORTs1OTs'},
#   'webUrl': 'http://www.hm.com/us/product/66190?article=66190-C'},
#  {'activityArticleNumber': '256463',
#   'additionalImages': [],
#   'articleCode': '58550-H',
#   'assortmentState': 'CURRENT',
#   'availableSizeInfo': [{'sizeName': '2', 'stockSize': '032'},
#    {'sizeName': '4', 'stockSize': '034'},
#    {'sizeName': '6', 'stockSize': '036'},
#    {'sizeName': '8', 'stockSize': '038'},
#    {'sizeName': '10', 'stockSize': '040'},
#    {'sizeName': '12', 'stockSize': '042'},
#    {'sizeName': '14', 'stockSize': '044'},
#    {'sizeName': '16', 'stockSize': '046'},
#    {'sizeName': '18', 'stockSize': '048'},
#    {'sizeName': '20', 'stockSize': '050'}],
#   'availableSwatches': [{'articleCode': '58550-H',
#     'castorArticleId': '0434429019',
#     'colour': 'f24e32',
#     'fabricImageResource': '/fabric/2016/B7E71B41-41EC-45C7-927A-7A431F918137.jpg',
#     'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2016/B7E71B41-41EC-45C7-927A-7A431F918137.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#   'castorArticleNumber': '019',
#   'castorProductNumber': '0434429',
#   'colourDescription': 'Powder',
#   'departments': [{'code': 'LADIES',
#     'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#     'paths': ['LADIES/LADIES_EVERYDAY_FASHION/LADIES_EVERYDAY_FASHION_TROUSERS_JEANS',
#      'LADIES/LADIES_TROUSERS/LADIES_TROUSERS_SLIM']}],
#   'name': 'Super-slim-fit Pants',
#   'priceInfo': {'currencyIso': 'USD',
#    'currencySymbol': '$',
#    'formattedOldPrice': '$19.99',
#    'formattedPrice': '$9.99',
#    'onSale': True,
#    'prefixCurrencySymbol': '$',
#    'price': 9.99,
#    'suffixCurrencySymbol': ''},
#   'primaryImage': {'type': 'STILL_LIFE_FRONT',
#    'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2016/E00 0434429 019 65 1008.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[1]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#   'productNumber': '58550',
#   'stockState': 'IN_STOCK',
#   'textualMarkers': [],
#   'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs1ODU1MC01X2VuX1VTOzU4NTUwLUhfZW5fVVM7O05PTkU6Tk9ORTs1OTs'},
#   'webUrl': 'http://www.hm.com/us/product/58550?article=58550-H'},
#  {'activityArticleNumber': '185653',
#   'additionalImages': [],
#   'articleCode': '66751-D',
#   'assortmentState': 'CURRENT',
#   'availableSizeInfo': [{'sizeName': 'L', 'stockSize': '006'}],
#   'availableSwatches': [{'articleCode': '66751-D',
#     'castorArticleId': '0459230009',
#     'colour': '807774',
#     'fabricImageResource': '/fabric/2017/129513AC-2403-46A2-A549-BAC86852DF14.jpg',
#     'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2017/129513AC-2403-46A2-A549-BAC86852DF14.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#   'castorArticleNumber': '009',
#   'castorProductNumber': '0459230',
#   'colourDescription': 'Gray melange',
#   'departments': [{'code': 'LADIES',
#     'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#     'paths': ['LADIES/LADIES_NIGHTWEAR/LADIES_NIGHTWEAR_PYJAMAS']}],
#   'name': 'Pajama Tank Top and Shorts',
#   'priceInfo': {'currencyIso': 'USD',
#    'currencySymbol': '$',
#    'formattedOldPrice': '$14.99',
#    'formattedPrice': '$7.99',
#    'onSale': True,
#    'prefixCurrencySymbol': '$',
#    'price': 7.99,
#    'suffixCurrencySymbol': ''},
#   'primaryImage': {'type': 'STILL_LIFE_FRONT',
#    'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2017/E00 0459230 009 00 1988.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[0]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#   'productNumber': '66751',
#   'stockState': 'IN_STOCK',
#   'textualMarkers': [],
#   'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs2Njc1MS00X2VuX1VTOzY2NzUxLURfZW5fVVM7O05PTkU6Tk9ORTs1OTs'},
#   'webUrl': 'http://www.hm.com/us/product/66751?article=66751-D'},
#  {'activityArticleNumber': '443598',
#   'additionalImages': [],
#   'articleCode': '61242-B',
#   'assortmentState': 'CURRENT',
#   'availableSizeInfo': [{'sizeName': 'XS', 'stockSize': '003'},
#    {'sizeName': 'S', 'stockSize': '004'},
#    {'sizeName': 'M', 'stockSize': '005'},
#    {'sizeName': 'L', 'stockSize': '006'}],
#   'availableSwatches': [{'articleCode': '61242-B',
#     'castorArticleId': '0452885003',
#     'colour': 'b8aba7',
#     'fabricImageResource': '/fabric/2016/469FC78E-FC24-46ED-9D6E-9319B6C535DF.jpg',
#     'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2016/469FC78E-FC24-46ED-9D6E-9319B6C535DF.jpg]&call=url[file:/mobile/v1/fabric/sprite]'},
#    {'articleCode': '61242-I',
#     'castorArticleId': '0452885013',
#     'colour': '008e4d',
#     'fabricImageResource': '/fabric/2017/5D78D05E-9C65-406D-8431-CAF0D81F4BC1.jpg',
#     'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2017/5D78D05E-9C65-406D-8431-CAF0D81F4BC1.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#   'castorArticleNumber': '003',
#   'castorProductNumber': '0452885',
#   'colourDescription': 'Light gray/swallows',
#   'departments': [{'code': 'LADIES',
#     'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#     'paths': ['LADIES/LADIES_CARDIGANS_JUMPERS/LADIES_CARDIGANS_JUMPERS_HOODIES',
#      'LADIES/LADIES_DIVIDED/LADIES_DIVIDED_HOODIES']}],
#   'name': 'Printed Sweatshirt',
#   'priceInfo': {'currencyIso': 'USD',
#    'currencySymbol': '$',
#    'formattedOldPrice': '$9.99',
#    'formattedPrice': '$5.99',
#    'onSale': True,
#    'prefixCurrencySymbol': '$',
#    'price': 5.99,
#    'suffixCurrencySymbol': ''},
#   'primaryImage': {'type': 'STILL_LIFE_FRONT',
#    'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2016/E00 0452885 003 42 0842.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[1]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#   'productNumber': '61242',
#   'stockState': 'IN_STOCK',
#   'textualMarkers': [],
#   'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs2MTI0Mi0xX2VuX1VTOzYxMjQyLUJfZW5fVVM7O05PTkU6Tk9ORTs1OTs'},
#   'webUrl': 'http://www.hm.com/us/product/61242?article=61242-B'},
#  {'activityArticleNumber': '740450',
#   'additionalImages': [],
#   'articleCode': '34312-M',
#   'assortmentState': 'CURRENT',
#   'availableSizeInfo': [{'sizeName': '34A', 'stockSize': '175'},
#    {'sizeName': '36A', 'stockSize': '180'},
#    {'sizeName': '32B', 'stockSize': '270'},
#    {'sizeName': '34B', 'stockSize': '275'},
#    {'sizeName': '36B', 'stockSize': '280'},
#    {'sizeName': '34C', 'stockSize': '375'},
#    {'sizeName': '36C', 'stockSize': '380'},
#    {'sizeName': '34D', 'stockSize': '475'},
#    {'sizeName': '36D', 'stockSize': '480'}],
#   'availableSwatches': [{'articleCode': '34312-M',
#     'castorArticleId': '0325087020',
#     'colour': '020f41',
#     'fabricImageResource': '/fabric/2016/CF4DAFA0-65A5-403A-95E2-31D6A83E6177.jpg',
#     'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2016/CF4DAFA0-65A5-403A-95E2-31D6A83E6177.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#   'castorArticleNumber': '020',
#   'castorProductNumber': '0325087',
#   'colourDescription': 'Pigeon blue/white',
#   'departments': [{'code': 'LADIES',
#     'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#     'paths': ['LADIES/LADIES_LINGERIE/LADIES_LINGERIE_BASIC',
#      'LADIES/LADIES_LINGERIE/LADIES_LINGERIE_BRA/LADIES_LINGERIE_BRA_PUSHUP',
#      'LADIES/LADIES_BASICS/LADIES_BASICS_LINGERIE']}],
#   'name': '2-pack Push-up Bras',
#   'priceInfo': {'currencyIso': 'USD',
#    'currencySymbol': '$',
#    'formattedOldPrice': '$17.99',
#    'formattedPrice': '$9.99',
#    'onSale': True,
#    'prefixCurrencySymbol': '$',
#    'price': 9.99,
#    'suffixCurrencySymbol': ''},
#   'primaryImage': {'type': 'STILL_LIFE_FRONT',
#    'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2016/E00 0325087 020 00 0942.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[0]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#   'productNumber': '34312',
#   'stockState': 'IN_STOCK',
#   'textualMarkers': [],
#   'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTszNDMxMi01X2VuX1VTOzM0MzEyLU1fZW5fVVM7O05PTkU6Tk9ORTs1OTs'},
#   'webUrl': 'http://www.hm.com/us/product/34312?article=34312-M'},
#  {'activityArticleNumber': '657829',
#   'additionalImages': [],
#   'articleCode': '68934-C',
#   'assortmentState': 'CURRENT',
#   'availableSizeInfo': [{'sizeName': 'XS', 'stockSize': '003'},
#    {'sizeName': 'S', 'stockSize': '004'},
#    {'sizeName': 'M', 'stockSize': '005'},
#    {'sizeName': 'L', 'stockSize': '006'},
#    {'sizeName': 'XL', 'stockSize': '007'}],
#   'availableSwatches': [{'articleCode': '68934-C',
#     'castorArticleId': '0500557001',
#     'colour': 'ffffff',
#     'fabricImageResource': '/fabric/2017/B34B3EA1-8D02-4EC4-A1A7-A902E7D215C3.jpg',
#     'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2017/B34B3EA1-8D02-4EC4-A1A7-A902E7D215C3.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#   'castorArticleNumber': '001',
#   'castorProductNumber': '0500557',
#   'colourDescription': 'White',
#   'departments': [{'code': 'LADIES',
#     'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#     'paths': ['LADIES/LADIES_TOPS/LADIES_TOPS_SHORT_SLEEVED',
#      'LADIES/LADIES_BASICS/LADIES_BASICS_TOPS/LADIES_BASICS_TOPS_SHORTSLEEVE']}],
#   'name': 'Jersey Top',
#   'priceInfo': {'currencyIso': 'USD',
#    'currencySymbol': '$',
#    'formattedOldPrice': '$12.99',
#    'formattedPrice': '$5.99',
#    'onSale': True,
#    'prefixCurrencySymbol': '$',
#    'price': 5.99,
#    'suffixCurrencySymbol': ''},
#   'primaryImage': {'type': 'STILL_LIFE_FRONT',
#    'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2017/E00 0500557 001 49 3191.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[1]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#   'productNumber': '68934',
#   'stockState': 'IN_STOCK',
#   'textualMarkers': [],
#   'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs2ODkzNC0xX2VuX1VTOzY4OTM0LUNfZW5fVVM7O05PTkU6Tk9ORTs1OTs'},
#   'webUrl': 'http://www.hm.com/us/product/68934?article=68934-C'},
#  {'activityArticleNumber': '034161',
#   'additionalImages': [],
#   'articleCode': '47586-J',
#   'assortmentState': 'CURRENT',
#   'availableSizeInfo': [{'sizeName': 'XS', 'stockSize': '003'},
#    {'sizeName': 'S', 'stockSize': '004'},
#    {'sizeName': 'M', 'stockSize': '005'},
#    {'sizeName': 'L', 'stockSize': '006'},
#    {'sizeName': 'XL', 'stockSize': '007'},
#    {'sizeName': 'XXL', 'stockSize': '008'}],
#   'availableSwatches': [{'articleCode': '47586-H',
#     'castorArticleId': '0371357019',
#     'colour': 'b8aba7',
#     'fabricImageResource': '/fabric/2017/82F5F363-2958-450B-9016-B1C7844E161F.jpg',
#     'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2017/82F5F363-2958-450B-9016-B1C7844E161F.jpg]&call=url[file:/mobile/v1/fabric/sprite]'},
#    {'articleCode': '47586-J',
#     'castorArticleId': '0371357020',
#     'colour': '5b3d25',
#     'fabricImageResource': '/fabric/2017/42BE525A-77C4-4855-9E6E-C1D6DCE2B334.jpg',
#     'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2017/42BE525A-77C4-4855-9E6E-C1D6DCE2B334.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#   'castorArticleNumber': '020',
#   'castorProductNumber': '0371357',
#   'colourDescription': 'Khaki green',
#   'departments': [{'code': 'MEN',
#     'name': 'NAVIGATION.LABEL.DEPARTMENT.MEN',
#     'paths': ['MEN/MEN_HM_MAN/MEN_HM_MAN_TSHIRTS_VESTS',
#      'MEN/MEN_TSHIRT/MEN_TSHIRT_SHORT_SLEEVED']}],
#   'name': 'Slub Jersey T-shirt',
#   'priceInfo': {'currencyIso': 'USD',
#    'currencySymbol': '$',
#    'formattedOldPrice': '$9.99',
#    'formattedPrice': '$5.99',
#    'onSale': True,
#    'prefixCurrencySymbol': '$',
#    'price': 5.99,
#    'suffixCurrencySymbol': ''},
#   'primaryImage': {'type': 'STILL_LIFE_FRONT',
#    'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2017/E00 0371357 020 28 2119.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[1]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#   'productNumber': '47586',
#   'stockState': 'IN_STOCK',
#   'textualMarkers': [],
#   'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs0NzU4Ni0xX2VuX1VTOzQ3NTg2LUpfZW5fVVM7O05PTkU6Tk9ORTs1OTs'},
#   'webUrl': 'http://www.hm.com/us/product/47586?article=47586-J'},
#  {'activityArticleNumber': '774075',
#   'additionalImages': [],
#   'articleCode': '24792-N',
#   'assortmentState': 'CURRENT',
#   'availableSizeInfo': [{'sizeName': 'XS', 'stockSize': '003'},
#    {'sizeName': 'S', 'stockSize': '004'},
#    {'sizeName': 'M', 'stockSize': '005'},
#    {'sizeName': 'L', 'stockSize': '006'},
#    {'sizeName': 'XL', 'stockSize': '007'}],
#   'availableSwatches': [{'articleCode': '24792-N',
#     'castorArticleId': '0129393047',
#     'colour': 'd6ba9a',
#     'fabricImageResource': '/fabric/2017/7163FDAE-A416-470E-961C-767AA0C7FA55.jpg',
#     'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2017/7163FDAE-A416-470E-961C-767AA0C7FA55.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#   'castorArticleNumber': '047',
#   'castorProductNumber': '0129393',
#   'colourDescription': 'Beige melange',
#   'departments': [{'code': 'LADIES',
#     'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#     'paths': ['LADIES/LADIES_CARDIGANS_JUMPERS/LADIES_CARDIGANS_JUMPERS_CARDIGANS',
#      'LADIES/LADIES_BASICS/LADIES_BASICS_CARDIGANSJUMPERS']}],
#   'name': 'Fine-knit Cardigan',
#   'priceInfo': {'currencyIso': 'USD',
#    'currencySymbol': '$',
#    'formattedOldPrice': '$17.99',
#    'formattedPrice': '$9.99',
#    'onSale': True,
#    'prefixCurrencySymbol': '$',
#    'price': 9.99,
#    'suffixCurrencySymbol': ''},
#   'primaryImage': {'type': 'STILL_LIFE_FRONT',
#    'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2017/E00 0129393 047 65 1883.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[1]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#   'productNumber': '24792',
#   'stockState': 'IN_STOCK',
#   'textualMarkers': [],
#   'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTsyNDc5Mi00X2VuX1VTOzI0NzkyLU5fZW5fVVM7O05PTkU6Tk9ORTs1OTs'},
#   'webUrl': 'http://www.hm.com/us/product/24792?article=24792-N'},
#  {'activityArticleNumber': '566804',
#   'additionalImages': [],
#   'articleCode': '63201-E',
#   'assortmentState': 'CURRENT',
#   'availableSizeInfo': [{'sizeName': '2', 'stockSize': '032'},
#    {'sizeName': '4', 'stockSize': '034'},
#    {'sizeName': '6', 'stockSize': '036'},
#    {'sizeName': '8', 'stockSize': '038'},
#    {'sizeName': '10', 'stockSize': '040'},
#    {'sizeName': '12', 'stockSize': '042'},
#    {'sizeName': '14', 'stockSize': '044'}],
#   'availableSwatches': [{'articleCode': '63201-E',
#     'castorArticleId': '0479205006',
#     'colour': 'c41503',
#     'fabricImageResource': '/fabric/2017/0799C72E-6D4B-494F-8673-3FB3BD1CFF07.jpg',
#     'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2017/0799C72E-6D4B-494F-8673-3FB3BD1CFF07.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#   'castorArticleNumber': '006',
#   'castorProductNumber': '0479205',
#   'colourDescription': 'Red',
#   'departments': [{'code': 'LADIES',
#     'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#     'paths': ['LADIES/LADIES_SHIRTS_BLOUSES/LADIES_SHIRTS_BLOUSES_BLOUSES',
#      'LADIES/LADIES_EVERYDAY_FASHION/LADIES_EVERYDAY_FASHION_SHIRTS_BLOUSES/LADIES_EVERYDAY_FASHION_SHIRTS_BLOUSES_BLOUSES']}],
#   'name': 'V-neck Blouse',
#   'priceInfo': {'currencyIso': 'USD',
#    'currencySymbol': '$',
#    'formattedOldPrice': '$17.99',
#    'formattedPrice': '$9.99',
#    'onSale': True,
#    'prefixCurrencySymbol': '$',
#    'price': 9.99,
#    'suffixCurrencySymbol': ''},
#   'primaryImage': {'type': 'STILL_LIFE_FRONT',
#    'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2017/E00 0479205 006 32 2439.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[1]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#   'productNumber': '63201',
#   'stockState': 'IN_STOCK',
#   'textualMarkers': [],
#   'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs2MzIwMS00X2VuX1VTOzYzMjAxLUVfZW5fVVM7O05PTkU6Tk9ORTs1OTs'},
#   'webUrl': 'http://www.hm.com/us/product/63201?article=63201-E'},
#  {'activityArticleNumber': '696117',
#   'additionalImages': [],
#   'articleCode': '94911-T',
#   'assortmentState': 'CURRENT',
#   'availableSizeInfo': [{'sizeName': 'XS', 'stockSize': '003'},
#    {'sizeName': 'S', 'stockSize': '004'},
#    {'sizeName': 'M', 'stockSize': '005'},
#    {'sizeName': 'L', 'stockSize': '006'}],
#   'availableSwatches': [{'articleCode': '94911-T',
#     'castorArticleId': '0298544038',
#     'colour': 'ffffff',
#     'fabricImageResource': '/fabric/2016/3613F072-29A8-4085-ABF5-A02665E85C47.jpg',
#     'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2016/3613F072-29A8-4085-ABF5-A02665E85C47.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#   'castorArticleNumber': '038',
#   'castorProductNumber': '0298544',
#   'colourDescription': 'White/Mickey Mouse',
#   'departments': [{'code': 'LADIES',
#     'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#     'paths': ['LADIES/LADIES_NIGHTWEAR/LADIES_NIGHTWEAR_PYJAMAS']}],
#   'name': 'Pajama Set with Top and Shorts',
#   'priceInfo': {'currencyIso': 'USD',
#    'currencySymbol': '$',
#    'formattedOldPrice': '$17.99',
#    'formattedPrice': '$9.99',
#    'onSale': True,
#    'prefixCurrencySymbol': '$',
#    'price': 9.99,
#    'suffixCurrencySymbol': ''},
#   'primaryImage': {'type': 'STILL_LIFE_FRONT',
#    'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2016/E00 0298544 038 00 1368.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[0]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#   'productNumber': '94911',
#   'stockState': 'IN_STOCK',
#   'textualMarkers': [],
#   'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs5NDkxMS0zLTAtMTFfZW5fVVM7OTQ5MTEtVF9lbl9VUzs7Tk9ORTpOT05FOzU5Ow'},
#   'webUrl': 'http://www.hm.com/us/product/94911?article=94911-T'},
#  {'activityArticleNumber': '804025',
#   'additionalImages': [],
#   'articleCode': '81801-P',
#   'assortmentState': 'CURRENT',
#   'availableSizeInfo': [{'sizeName': '6', 'stockSize': '036'},
#    {'sizeName': '8', 'stockSize': '038'},
#    {'sizeName': '10', 'stockSize': '040'}],
#   'availableSwatches': [{'articleCode': '81801-P',
#     'castorArticleId': '0304946027',
#     'colour': '020f41',
#     'fabricImageResource': '/fabric/2016/A6403ABC-51B3-4C2A-9C8F-9CDE2129B2B5.jpg',
#     'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2016/A6403ABC-51B3-4C2A-9C8F-9CDE2129B2B5.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#   'castorArticleNumber': '027',
#   'castorProductNumber': '0304946',
#   'colourDescription': 'Dark denim blue',
#   'departments': [{'code': 'LADIES',
#     'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#     'paths': ['LADIES/LADIES_TROUSERS/LADIES_TROUSERS_SLIM',
#      'LADIES/LADIES_DIVIDED/LADIES_DIVIDED_TROUSERS']}],
#   'name': 'Slim-fit Pants',
#   'priceInfo': {'currencyIso': 'USD',
#    'currencySymbol': '$',
#    'formattedOldPrice': '$12.99',
#    'formattedPrice': '$5.99',
#    'onSale': True,
#    'prefixCurrencySymbol': '$',
#    'price': 5.99,
#    'suffixCurrencySymbol': ''},
#   'primaryImage': {'type': 'STILL_LIFE_FRONT',
#    'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2016/E00 0304946 027 42 1074.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[1]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#   'productNumber': '81801',
#   'stockState': 'IN_STOCK',
#   'textualMarkers': [],
#   'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs4MTgwMS0xX2VuX1VTOzgxODAxLVBfZW5fVVM7O05PTkU6Tk9ORTs1OTs'},
#   'webUrl': 'http://www.hm.com/us/product/81801?article=81801-P'},
#  {'activityArticleNumber': '758090',
#   'additionalImages': [],
#   'articleCode': '67827-A',
#   'assortmentState': 'CURRENT',
#   'availableSizeInfo': [{'sizeName': 'XS', 'stockSize': '003'},
#    {'sizeName': 'S', 'stockSize': '004'},
#    {'sizeName': 'M', 'stockSize': '005'},
#    {'sizeName': 'L', 'stockSize': '006'}],
#   'availableSwatches': [{'articleCode': '67827-A',
#     'castorArticleId': '0515514002',
#     'colour': '000000',
#     'fabricImageResource': '/fabric/2017/952F6136-6E21-413A-9CC2-F9EF95E355BA.jpg',
#     'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2017/952F6136-6E21-413A-9CC2-F9EF95E355BA.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#   'castorArticleNumber': '002',
#   'castorProductNumber': '0515514',
#   'colourDescription': 'Black',
#   'departments': [{'code': 'LADIES',
#     'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#     'paths': ['LADIES/LADIES_TOPS/LADIES_TOPS_SHORT_SLEEVED',
#      'LADIES/LADIES_DIVIDED/LADIES_DIVIDED_TOPS/LADIES_DIVIDED_TOPS_SHORTSLEEVE']}],
#   'name': 'Crinkled Kimono',
#   'priceInfo': {'currencyIso': 'USD',
#    'currencySymbol': '$',
#    'formattedOldPrice': '$19.99',
#    'formattedPrice': '$9.99',
#    'onSale': True,
#    'prefixCurrencySymbol': '$',
#    'price': 9.99,
#    'suffixCurrencySymbol': ''},
#   'primaryImage': {'type': 'STILL_LIFE_FRONT',
#    'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2017/E00 0515514 002 21 3569.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[1]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#   'productNumber': '67827',
#   'stockState': 'IN_STOCK',
#   'textualMarkers': [],
#   'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs2NzgyNy0xX2VuX1VTOzY3ODI3LUFfZW5fVVM7O05PTkU6Tk9ORTs1OTs'},
#   'webUrl': 'http://www.hm.com/us/product/67827?article=67827-A'},
#  {'activityArticleNumber': '744801',
#   'additionalImages': [],
#   'articleCode': '58550-D',
#   'assortmentState': 'CURRENT',
#   'availableSizeInfo': [{'sizeName': '2', 'stockSize': '032'},
#    {'sizeName': '4', 'stockSize': '034'},
#    {'sizeName': '6', 'stockSize': '036'},
#    {'sizeName': '8', 'stockSize': '038'},
#    {'sizeName': '10', 'stockSize': '040'},
#    {'sizeName': '12', 'stockSize': '042'},
#    {'sizeName': '14', 'stockSize': '044'},
#    {'sizeName': '16', 'stockSize': '046'},
#    {'sizeName': '18', 'stockSize': '048'},
#    {'sizeName': '20', 'stockSize': '050'}],
#   'availableSwatches': [{'articleCode': '58550-D',
#     'castorArticleId': '0434429007',
#     'colour': '807774',
#     'fabricImageResource': '/fabric/2016/BB43C92F-E514-4CF3-818B-61151BF75636.jpg',
#     'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2016/BB43C92F-E514-4CF3-818B-61151BF75636.jpg]&call=url[file:/mobile/v1/fabric/sprite]'},
#    {'articleCode': '58550-E',
#     'castorArticleId': '0434429013',
#     'colour': '3c3837',
#     'fabricImageResource': '/fabric/2016/5E1E9961-B85B-435C-B15B-E11D902E3184.jpg',
#     'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2016/5E1E9961-B85B-435C-B15B-E11D902E3184.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#   'castorArticleNumber': '007',
#   'castorProductNumber': '0434429',
#   'colourDescription': 'Gray denim',
#   'departments': [{'code': 'LADIES',
#     'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#     'paths': ['LADIES/LADIES_EVERYDAY_FASHION/LADIES_EVERYDAY_FASHION_TROUSERS_JEANS',
#      'LADIES/LADIES_TROUSERS/LADIES_TROUSERS_SLIM']}],
#   'name': 'Super-slim-fit Pants',
#   'priceInfo': {'currencyIso': 'USD',
#    'currencySymbol': '$',
#    'formattedOldPrice': '$19.99',
#    'formattedPrice': '$9.99',
#    'onSale': True,
#    'prefixCurrencySymbol': '$',
#    'price': 9.99,
#    'suffixCurrencySymbol': ''},
#   'primaryImage': {'type': 'STILL_LIFE_FRONT',
#    'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2016/E00 0434429 007 52 1225.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[4]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#   'productNumber': '58550',
#   'stockState': 'IN_STOCK',
#   'textualMarkers': [],
#   'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs1ODU1MC0zX2VuX1VTOzU4NTUwLURfZW5fVVM7O05PTkU6Tk9ORTs1OTs'},
#   'webUrl': 'http://www.hm.com/us/product/58550?article=58550-D'},
#  {'activityArticleNumber': '798894',
#   'additionalImages': [],
#   'articleCode': '69910-A',
#   'assortmentState': 'CURRENT',
#   'availableSizeInfo': [{'sizeName': 'XS', 'stockSize': '003'},
#    {'sizeName': 'S', 'stockSize': '004'},
#    {'sizeName': 'M', 'stockSize': '005'},
#    {'sizeName': 'L', 'stockSize': '006'},
#    {'sizeName': 'XL', 'stockSize': '007'}],
#   'availableSwatches': [{'articleCode': '69910-A',
#     'castorArticleId': '0532919002',
#     'colour': '1c0939',
#     'fabricImageResource': '/fabric/2017/01EAC719-CEAB-4101-BB5B-31D45E7875E1.jpg',
#     'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2017/01EAC719-CEAB-4101-BB5B-31D45E7875E1.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#   'castorArticleNumber': '002',
#   'castorProductNumber': '0532919',
#   'colourDescription': 'Dark blue',
#   'departments': [{'code': 'LADIES',
#     'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#     'paths': ['LADIES/LADIES_TOPS/LADIES_TOPS_SHORT_SLEEVED',
#      'LADIES/LADIES_CASUAL/LADIES_CASUAL_TOPS']}],
#   'name': 'Wide-cut Top',
#   'priceInfo': {'currencyIso': 'USD',
#    'currencySymbol': '$',
#    'formattedOldPrice': '$17.99',
#    'formattedPrice': '$7.99',
#    'onSale': True,
#    'prefixCurrencySymbol': '$',
#    'price': 7.99,
#    'suffixCurrencySymbol': ''},
#   'primaryImage': {'type': 'STILL_LIFE_FRONT',
#    'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2017/E00 0532919 002 87 3615.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[2]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#   'productNumber': '69910',
#   'stockState': 'IN_STOCK',
#   'textualMarkers': [],
#   'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs2OTkxMC0xX2VuX1VTOzY5OTEwLUFfZW5fVVM7O05PTkU6Tk9ORTs1OTs'},
# ...
#   'priceInfo': {'currencyIso': 'USD',
#    'currencySymbol': '$',
#    'formattedOldPrice': '$24.99',
#    'formattedPrice': '$9.99',
#    'onSale': True,
#    'prefixCurrencySymbol': '$',
#    'price': 9.99,
#    'suffixCurrencySymbol': ''},
#   'primaryImage': {'type': 'STILL_LIFE_FRONT',
#    'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2017/E00 0477052 001 65 1822.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[1]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#   'productNumber': '66046',
#   'stockState': 'IN_STOCK',
#   'textualMarkers': [],
#   'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs2NjA0Ni00X2VuX1VTOzY2MDQ2LUJfZW5fVVM7O05PTkU6Tk9ORTs1OTs'},
#   'webUrl': 'http://www.hm.com/us/product/66046?article=66046-B'},
#  {'activityArticleNumber': '568140',
#   'additionalImages': [],
#   'articleCode': '63019-Q',
#   'assortmentState': 'CURRENT',
#   'availableSizeInfo': [{'sizeName': 'XS', 'stockSize': '003'},
#    {'sizeName': 'S', 'stockSize': '004'},
#    {'sizeName': 'M', 'stockSize': '005'},
#    {'sizeName': 'L', 'stockSize': '006'},
#    {'sizeName': 'XL', 'stockSize': '007'}],
#   'availableSwatches': [{'articleCode': '63019-Q',
#     'castorArticleId': '0465861021',
#     'colour': 'dc3343',
#     'fabricImageResource': '/fabric/2017/827D2507-2B03-461C-853C-B015131949C5.jpg',
#     'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2017/827D2507-2B03-461C-853C-B015131949C5.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#   'castorArticleNumber': '021',
#   'castorProductNumber': '0465861',
#   'colourDescription': 'Red',
#   'departments': [{'code': 'LADIES',
#     'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#     'paths': ['LADIES/LADIES_TOPS/LADIES_TOPS_SHORT_SLEEVED',
#      'LADIES/LADIES_CASUAL/LADIES_CASUAL_TOPS']}],
#   'name': 'T-shirt with Printed Design',
#   'priceInfo': {'currencyIso': 'USD',
#    'currencySymbol': '$',
#    'formattedOldPrice': '$12.99',
#    'formattedPrice': '$5.99',
#    'onSale': True,
#    'prefixCurrencySymbol': '$',
#    'price': 5.99,
#    'suffixCurrencySymbol': ''},
#   'primaryImage': {'type': 'STILL_LIFE_FRONT',
#    'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2017/E00 0465861 021 82 1979.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[1]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#   'productNumber': '63019',
#   'stockState': 'IN_STOCK',
#   'textualMarkers': [],
#   'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs2MzAxOS0yX2VuX1VTOzYzMDE5LVFfZW5fVVM7O05PTkU6Tk9ORTs1OTs'},
#   'webUrl': 'http://www.hm.com/us/product/63019?article=63019-Q'},
#  {'activityArticleNumber': '833909',
#   'additionalImages': [],
#   'articleCode': '40949-A',
#   'assortmentState': 'CURRENT',
#   'availableSizeInfo': [{'sizeName': 'XS', 'stockSize': '003'},
#    {'sizeName': 'S', 'stockSize': '004'},
#    {'sizeName': 'M', 'stockSize': '005'},
#    {'sizeName': 'L', 'stockSize': '006'},
#    {'sizeName': 'XL', 'stockSize': '007'}],
#   'availableSwatches': [{'articleCode': '40949-A',
#     'castorArticleId': '0249165005',
#     'colour': '000000',
#     'fabricImageResource': '/fabric/2016/106EDFB7-8FAF-4E95-8258-9C5C11318C39.jpg',
#     'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2016/106EDFB7-8FAF-4E95-8258-9C5C11318C39.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#   'castorArticleNumber': '005',
#   'castorProductNumber': '0249165',
#   'colourDescription': 'Black',
#   'departments': [{'code': 'LADIES',
#     'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#     'paths': ['LADIES/LADIES_MATERNITY_WEAR/LADIES_MATERNITY_WEAR_TOPS',
#      'LADIES/LADIES_MATERNITY_WEAR/LADIES_MATERNITY_WEAR_BASIC',
#      'LADIES/LADIES_SELECTED/LADIES_SELECTED_CONSCIOUS-SUSTAINABLE-STYLE']}],
#   'name': 'MAMA Jersey Top',
#   'priceInfo': {'currencyIso': 'USD',
#    'currencySymbol': '$',
#    'formattedOldPrice': '$12.99',
#    'formattedPrice': '$5.99',
#    'onSale': True,
#    'prefixCurrencySymbol': '$',
#    'price': 5.99,
#    'suffixCurrencySymbol': ''},
#   'primaryImage': {'type': 'STILL_LIFE_FRONT',
#    'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2014/A00 0249165 005 97 2130.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[2]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#   'productMarker': {'markerDescription': '',
#    'markerText': 'CONSCIOUS',
#    'markerType': 'CONSCIOUS'},
#   'productNumber': '40949',
#   'stockState': 'IN_STOCK',
#   'textualMarkers': [],
#   'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs0MDk0OS01X2VuX1VTOzQwOTQ5LUFfZW5fVVM7O05PTkU6Tk9ORTs1OTs'},
#   'webUrl': 'http://www.hm.com/us/product/40949?article=40949-A'},
#  {'activityArticleNumber': '229549',
#   'additionalImages': [],
#   'articleCode': '61847-A',
#   'assortmentState': 'CURRENT',
#   'availableSizeInfo': [{'sizeName': '2', 'stockSize': '032'},
#    {'sizeName': '6', 'stockSize': '036'},
#    {'sizeName': '8', 'stockSize': '038'},
#    {'sizeName': '10', 'stockSize': '040'},
#    {'sizeName': '12', 'stockSize': '042'},
#    {'sizeName': '14', 'stockSize': '044'}],
#   'availableSwatches': [{'articleCode': '61847-A',
#     'castorArticleId': '0475025001',
#     'colour': '000000',
#     'fabricImageResource': '/fabric/2016/F65E21FF-7F39-4AFA-B15D-25E32962930D.jpg',
#     'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2016/F65E21FF-7F39-4AFA-B15D-25E32962930D.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#   'castorArticleNumber': '001',
#   'castorProductNumber': '0475025',
#   'colourDescription': 'Black',
#   'departments': [{'code': 'LADIES',
#     'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#     'paths': ['LADIES/LADIES_EVERYDAY_FASHION/LADIES_EVERYDAY_FASHION_TROUSERS_JEANS',
#      'LADIES/LADIES_TROUSERS/LADIES_TROUSERS_DRESSED']}],
#   'name': 'Suit Pants',
#   'priceInfo': {'currencyIso': 'USD',
#    'currencySymbol': '$',
#    'formattedOldPrice': '$24.99',
#    'formattedPrice': '$14.99',
#    'onSale': True,
#    'prefixCurrencySymbol': '$',
#    'price': 14.99,
#    'suffixCurrencySymbol': ''},
#   'primaryImage': {'type': 'STILL_LIFE_FRONT',
#    'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2016/E00 0475025 001 62 1669.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[1]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#   'productNumber': '61847',
#   'stockState': 'IN_STOCK',
#   'textualMarkers': [],
#   'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs2MTg0Ny0xX2VuX1VTOzYxODQ3LUFfZW5fVVM7O05PTkU6Tk9ORTs1OTs'},
#   'webUrl': 'http://www.hm.com/us/product/61847?article=61847-A'},
#  {'activityArticleNumber': '781654',
#   'additionalImages': [],
#   'articleCode': '67635-A',
#   'assortmentState': 'CURRENT',
#   'availableSizeInfo': [{'sizeName': '2', 'stockSize': '032'},
#    {'sizeName': '4', 'stockSize': '034'},
#    {'sizeName': '6', 'stockSize': '036'},
#    {'sizeName': '8', 'stockSize': '038'},
#    {'sizeName': '10', 'stockSize': '040'},
#    {'sizeName': '12', 'stockSize': '042'},
#    {'sizeName': '14', 'stockSize': '044'},
#    {'sizeName': '16', 'stockSize': '046'}],
#   'availableSwatches': [{'articleCode': '67635-A',
#     'castorArticleId': '0518382001',
#     'colour': '161e80',
#     'fabricImageResource': '/fabric/2017/513C8C25-48D0-4695-9624-B6BFC7D5DBD3.jpg',
#     'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2017/513C8C25-48D0-4695-9624-B6BFC7D5DBD3.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#   'castorArticleNumber': '001',
#   'castorProductNumber': '0518382',
#   'colourDescription': 'Denim blue',
#   'departments': [{'code': 'LADIES',
#     'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#     'paths': ['LADIES/LADIES_SKIRTS/LADIES_SKIRTS_SHORT',
#      'LADIES/LADIES_CASUAL/LADIES_CASUAL_SKIRTS']}],
#   'name': 'Denim Skirt',
#   'priceInfo': {'currencyIso': 'USD',
#    'currencySymbol': '$',
#    'formattedOldPrice': '$34.99',
#    'formattedPrice': '$12.99',
#    'onSale': True,
#    'prefixCurrencySymbol': '$',
#    'price': 12.99,
#    'suffixCurrencySymbol': ''},
#   'primaryImage': {'type': 'STILL_LIFE_FRONT',
#    'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2017/E00 0518382 001 82 3284.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[1]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#   'productNumber': '67635',
#   'stockState': 'IN_STOCK',
#   'textualMarkers': [],
#   'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs2NzYzNS0xX2VuX1VTOzY3NjM1LUFfZW5fVVM7O05PTkU6Tk9ORTs1OTs'},
#   'webUrl': 'http://www.hm.com/us/product/67635?article=67635-A'},
#  {'activityArticleNumber': '359418',
#   'additionalImages': [],
#   'articleCode': '63058-C',
#   'assortmentState': 'CURRENT',
#   'availableSizeInfo': [{'sizeName': 'XS', 'stockSize': '003'},
#    {'sizeName': 'S', 'stockSize': '004'},
#    {'sizeName': 'M', 'stockSize': '005'},
#    {'sizeName': 'L', 'stockSize': '006'}],
#   'availableSwatches': [{'articleCode': '63058-C',
#     'castorArticleId': '0485973004',
#     'colour': 'ffffff',
#     'fabricImageResource': '/fabric/2017/24CF9B62-31BD-4477-935E-FBF426915E31.jpg',
#     'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2017/24CF9B62-31BD-4477-935E-FBF426915E31.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#   'castorArticleNumber': '004',
#   'castorProductNumber': '0485973',
#   'colourDescription': 'White',
#   'departments': [{'code': 'LADIES',
#     'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#     'paths': ['LADIES/LADIES_TOPS/LADIES_TOPS_SHORT_SLEEVED',
#      'LADIES/LADIES_DIVIDED/LADIES_DIVIDED_TOPS/LADIES_DIVIDED_TOPS_SHORTSLEEVE']}],
#   'name': 'V-neck Jersey Top',
#   'priceInfo': {'currencyIso': 'USD',
#    'currencySymbol': '$',
#    'formattedOldPrice': '$12.99',
#    'formattedPrice': '$9.99',
#    'onSale': True,
#    'prefixCurrencySymbol': '$',
#    'price': 9.99,
#    'suffixCurrencySymbol': ''},
#   'primaryImage': {'type': 'STILL_LIFE_FRONT',
#    'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2017/E00 0485973 004 12 2798.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[1]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#   'productNumber': '63058',
#   'stockState': 'IN_STOCK',
#   'textualMarkers': [],
#   'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs2MzA1OC0zX2VuX1VTOzYzMDU4LUNfZW5fVVM7O05PTkU6Tk9ORTs1OTs'},
#   'webUrl': 'http://www.hm.com/us/product/63058?article=63058-C'},
#  {'activityArticleNumber': '026036',
#   'additionalImages': [],
#   'articleCode': '63139-F',
#   'assortmentState': 'CURRENT',
#   'availableSizeInfo': [{'sizeName': 'XS', 'stockSize': '003'},
#    {'sizeName': 'S', 'stockSize': '004'},
#    {'sizeName': 'M', 'stockSize': '005'},
#    {'sizeName': 'L', 'stockSize': '006'},
#    {'sizeName': 'XL', 'stockSize': '007'}],
#   'availableSwatches': [{'articleCode': '63139-F',
#     'castorArticleId': '0479555011',
#     'colour': '90e6cd',
#     'fabricImageResource': '/fabric/2017/6122482C-DAC9-420D-B3C7-6C09E08857CD.jpg',
#     'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2017/6122482C-DAC9-420D-B3C7-6C09E08857CD.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#   'castorArticleNumber': '011',
#   'castorProductNumber': '0479555',
#   'colourDescription': 'Light turquoise',
#   'departments': [{'code': 'LADIES',
#     'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#     'paths': ['LADIES/LADIES_CARDIGANS_JUMPERS/LADIES_CARDIGANS_JUMPERS_JUMPERS',
#      'LADIES/LADIES_BASICS/LADIES_BASICS_CARDIGANSJUMPERS']}],
#   'name': 'Fine-knit Sweater',
#   'priceInfo': {'currencyIso': 'USD',
#    'currencySymbol': '$',
#    'formattedOldPrice': '$24.99',
#    'formattedPrice': '$9.99',
#    'onSale': True,
#    'prefixCurrencySymbol': '$',
#    'price': 9.99,
#    'suffixCurrencySymbol': ''},
#   'primaryImage': {'type': 'STILL_LIFE_FRONT',
#    'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2017/E00 0479555 011 65 1862.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[3]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#   'productNumber': '63139',
#   'stockState': 'IN_STOCK',
#   'textualMarkers': [],
#   'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs2MzEzOS0yX2VuX1VTOzYzMTM5LUZfZW5fVVM7O05PTkU6Tk9ORTs1OTs'},
#   'webUrl': 'http://www.hm.com/us/product/63139?article=63139-F'},
#  {'activityArticleNumber': '093299',
#   'additionalImages': [],
#   'articleCode': '51558-K',
#   'assortmentState': 'CURRENT',
#   'availableSizeInfo': [{'sizeName': '30R', 'stockSize': '044'},
#    {'sizeName': '32R', 'stockSize': '046'},
#    {'sizeName': '33R', 'stockSize': '048'},
#    {'sizeName': '34R', 'stockSize': '050'},
#    {'sizeName': '36R', 'stockSize': '052'},
#    {'sizeName': '38R', 'stockSize': '054'},
#    {'sizeName': '40R', 'stockSize': '056'},
#    {'sizeName': '42R', 'stockSize': '058'},
#    {'sizeName': '44R', 'stockSize': '060'},
#    {'sizeName': '46R', 'stockSize': '062'}],
#   'availableSwatches': [{'articleCode': '51558-K',
#     'castorArticleId': '0417081018',
#     'colour': '1c0939',
#     'fabricImageResource': '/fabric/2016/8F184017-3379-4C78-B5E9-D6BACCC6946D.jpg',
#     'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2016/8F184017-3379-4C78-B5E9-D6BACCC6946D.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#   'castorArticleNumber': '018',
#   'castorProductNumber': '0417081',
#   'colourDescription': 'Dark blue',
#   'departments': [{'code': 'MEN',
#     'name': 'NAVIGATION.LABEL.DEPARTMENT.MEN',
#     'paths': ['MEN/MEN_HM_MAN/MEN_HM_MAN_TROUSERS_JEANS',
#      'MEN/MEN_TROUSERS/MEN_TROUSERS_CHINOS']}],
#   'name': 'Chinos Skinny fit',
#   'priceInfo': {'currencyIso': 'USD',
#    'currencySymbol': '$',
#    'formattedOldPrice': '$29.99',
#    'formattedPrice': '$14.99',
#    'onSale': True,
#    'prefixCurrencySymbol': '$',
#    'price': 14.99,
#    'suffixCurrencySymbol': ''},
#   'primaryImage': {'type': 'STILL_LIFE_FRONT',
#    'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2016/E00 0417081 018 98 1501.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[1]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#   'productNumber': '51558',
#   'stockState': 'IN_STOCK',
#   'textualMarkers': [],
#   'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs1MTU1OC0yX2VuX1VTOzUxNTU4LUtfZW5fVVM7O05PTkU6Tk9ORTs1OTs'},
#   'webUrl': 'http://www.hm.com/us/product/51558?article=51558-K'}]

# %% [markdown]
# ### What is the tag name and class name for the old price? The new price?

# %%
data = doc.find_all('priceInfo', { 'currencyIso': 'USD' })
 #{ 'class': 'story' }
    
for data in data:
print("This is a story")
headline = story.find('h2', { 'class': 'story-heading' })
print(headline.text)

for i in data:
	if i['product']=='Jeans'
	price = i['price']
	old_price = price['old=price']
	print(old_price)

# %%
data = [{'product':'Top', 'price': {'old_price', 'new_price'3}}]
# Out:
#   File "<ipython-input-17-8a9e45e0016f>", line 1
#     data = [{'product':'Top', 'price': {'old_price', 'new_price'3}}]
#                                                                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### What is the tag name and class name for the link to the product page?

# %% [markdown]
# ## Setup: Import what you'll need to scrape the page
#
# Use `requests`, not `urllib`.

# %%
http://www.hm.com/us/department/MEN

# %% [markdown]
# ## Try to scrape the page: how many product names can you find?
#
# "Try" to do it, because it *will not work.* Once you've learned that it won't work, spend a few minutes **looking at the page code** to see if you can figure out why.
#
# Eventually, ask for help by writing on the board.

# %% [markdown]
# ## URLs

# %% [markdown]
# ### What is the URL for data about on-sale men's clothing?

# %% [markdown]
# ### What is the URL for data about on-sale women's clothing?

# %% [markdown]
# ### What is the URL for data about on-sale women's tops?

# %% [markdown]
# ### What changes about the url based on what you're looking for?

# %% [markdown]
# ## Request on-sale women's tops.
#
# ### How many results do you get?

# %% [markdown]
# ### How many total results are there? How do you change the URL to get more?
#
# There are a few ways to change the URL to: there is one very easy way and one a-little-difficult way.

# %% [markdown]
# ### Download all on-sale women's tops and save them to a CSV.
#
# I want this CSV to include
#
# - Name
# - Product code/number
# - Old price
# - On-sale price
# - Item's URL

# %% [markdown]
# ## Analyzing on-sale items
#
# ### Read in the on-sale CSV and make sure the data looks right

# %% [markdown]
# ### Convert the prices to numbers, if you haven't already

# %% [markdown]
# ### What is the average on-sale price of a women's top? Make a histogram, too, please.

# %% [markdown]
# ### What is the average discount between full price and on sale? Histogram too, please.

# %% [markdown]
# ### What is the average discount as a percentage of the full price? Histogram too, please.

# %% [markdown]
# ## Shopping the sales
#
# ### How many items are over 50% off?

# %% [markdown]
# ### Display all items above 50% off.
#
# Pandas doesn't want to show you every row. Change its settings so it will display up to **200 rows of content.**
