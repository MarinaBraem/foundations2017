# %% [markdown]
# # Corporate Prosecution - Exercise B
#
# #### Summary
#
# Looking at corporate prosecutions over time, and the possible assignment of a compliance officer.
#
# #### Files
#
# - cpr-data.xls, "detailed information about every federal organizational prosecution since 2001, as well as deferred and non-prosecution agreements with organizations since 1990"
#
# #### Data Source(s)
#
# The UVA School of Law publishees a [Corpoate Prosecution Registry](http://lib.law.virginia.edu/Garrett/corporate-prosecution-registry/about.html)
#
# > The goal of this Corporate Prosecutions Registry is to provide comprehensive and up-to-date information on federal organizational prosecutions in the United States, so that we can better understand how corporate prosecutions are brought and resolved. We include detailed information about every federal organizational prosecution since 2001, as well as deferred and non-prosecution agreements with organizations since 1990.
#
# [Corpoate Prosecution Registry](http://lib.law.virginia.edu/Garrett/corporate-prosecution-registry/about.html)
#
# #### Skills
#
# - Working with CSV files
# - Counting and summarizing columns
# - Searching with strings
# - Extracting with strings

# %% [markdown]
# # Read in `cpr-data.csv`

# %%
import pandas as pd 

df = pd.read_csv("cpr-data.csv")
df.head()
import matplotlib
# %matplotlib inline

# %% [markdown]
# ### Check that your dataframe has 3038 rows and 56 columns.

# %%
df.shape
# Out:
# (3038, 56)

# %% [markdown]
# ### List the columns and their data types

# %%
df.dtypes.head(20)
# Out:
# REC_ID                                     int64
# COMPANY                                   object
# DISPOSITION_TYPE                          object
# PRIMARY_CRIME_CODE                        object
# SWISS_BANK_PROGRAM                        object
# USAO                                      object
# COUNTRY                                   object
# FINANCIAL_INSTITUTION                     object
# CASE_NAME                                 object
# CASE_ID                                   object
# DOCKET_NO                                 object
# DATE                                      object
# JUDGMENT_DATE                             object
# PLEA_DATE                                 object
# TICKER                                    object
# US_PUBLIC_CO                              object
# ADDITIONAL_REGULATORY_FINE_OR_PAYMENT    float64
# COMMUNITY_SERVICE_OR_OTHER               float64
# FINE                                     float64
# FORFEITURE_DISGORGEMENT                  float64
# dtype: object

# %% [markdown]
# ### What do the following columns mean?
#
# - PRIMARY_CRIME_CODE
# - DISPOSITION_TYPE
# - AGREEMENT_TYPE
# - COUNTRY
# - FINE
# - TOTAL_PAYMENT
# - USAO
# - PROBATION_LENGTH
# - AGREEMENT_REQUIRED_NEW_POSITIONS
# - INDEP_MONITOR_REQUIRED

# %%
#This re legends to the different colomns (Keys)

# %% [markdown]
# # Customizing the display in pandas
#
# See how the middle of the table has a `...`? Let's fix that.
#
# ## How do you see the number of columns pandas will display?

# %%
len(df.columns)
# Out:
# 56

# %% [markdown]
# ## Set pandas to display 65 columns

# %%
pd.set_option("display.max_columns", 65)
df
# Out:
#       REC_ID                                 COMPANY DISPOSITION_TYPE  \
# 0        138  1st Union Transfer and Telegraph, Inc.             plea
# 1        139                3D Poultry Loading, Inc.             plea
# 2       2529                         3rd & Bell, LLC             plea
# 3        822                          41 Market Inc.             plea
# 4        140                            45,000, Inc.             plea
# 5        823                         4628 Group Inc.             plea
# 6        824                           70 North, LLC             plea
# 7        825                       806 Trading Corp.             plea
# 8       2530                 83rd & Union Hills, LLC             plea
# 9       2531                        84th & Bell, LLC             plea
# ...      ...                                     ...              ...
# 3028    2516                      ZHU & Partners LLC             plea
# 3029    2711     Zavos Diagnostic Laboratories, Inc.             plea
# 3030    2517                   Zein Automobiles Inc.             plea
# 3031    2923                       Zentner & Zentner             plea
# 3032    2518                          Zeon Chemicals             plea
# 3033    2523                   Zimmer Holdings, Inc.               DP
# 3034     136                      Zuger Kantonalbank               NP
# 3035    3077                     Zwanger-Pesiri Inc.             plea
# 3036     253                             e-gold Ltd.             plea
# 3037    2585                               eAir, LLC             plea
#
#                             PRIMARY_CRIME_CODE SWISS_BANK_PROGRAM  \
# 0                             Money Laundering                NaN
# 1                                  Immigration                NaN
# 2                                  Immigration                NaN
# 3     Controlled substances / Drugs / Meth Act                NaN
# 4                                Environmental                NaN
# 5                                Environmental                NaN
# 6                                Environmental                NaN
# 7                                        Other                NaN
# 8                                  Immigration                NaN
# 9                                  Immigration                NaN
# ...                                        ...                ...
# 3028                               Immigration                NaN
# 3029                                     Other                NaN
# 3030                        Fraud - Accounting                NaN
# 3031                                  Wildlife                NaN
# 3032                                 Antitrust                NaN
# 3033                                 Kickbacks                 No
# 3034                               Fraud - Tax                Yes
# 3035                       Fraud - Health Care                NaN
# 3036                          Money Laundering                NaN
# 3037                             Environmental                NaN
#
#                                                    USAO  \
# 0                           Virginia - Eastern District
# 1                           Arkansas - Western District
# 2                                               Arizona
# 3                           Georgia - Northern District
# 4                           Louisiana - Middle District
# 5                          New York - Northern District
# 6                                                Alaska
# 7                                            New Jersey
# 8                                               Arizona
# 9                                               Arizona
# ...                                                 ...
# 3028                                           Maryland
# 3029                        Kentucky - Eastern District
# 3030                      Washington - Western District
# 3031  USDOJ - Environment & Natural Resources Divisi...
# 3032                         USDOJ - Antitrust Division
# 3033                                         New Jersey
# 3034                               USDOJ - Tax Division
# 3035                        New York - Eastern District
# 3036  District of Columbia,USDOJ - Criminal Division...
# 3037                        Florida - Southern District
#
#                     COUNTRY FINANCIAL_INSTITUTION  \
# 0             United States                   Yes
# 1             United States                    No
# 2             United States                    No
# 3             United States                    No
# 4             United States                    No
# 5             United States                    No
# 6             United States                    No
# 7             United States                    No
# 8             United States                    No
# 9             United States                    No
# ...                     ...                   ...
# 3028          United States                    No
# 3029          United States                    No
# 3030          United States                    No
# 3031          United States                    No
# 3032          United States                    No
# 3033          United States                    No
# 3034            Switzerland                   Yes
# 3035          United States                    No
# 3036  Saint Kitts and Nevis                   Yes
# 3037          United States                    No
#
#                                          CASE_NAME        CASE_ID DOCKET_NO  \
# 0                        USA v. 1st Union Transfer  4:03-cr-00024         8
# 1                        USA v. 3D Poultry Loading  2:04-cr-20061         7
# 2     USA v. Danny's Management Services LLC et al  2:13-cr-01143       510
# 3                            USA v. 41 Market Inc.  4:06-cr-00023        11
# 4                                 USA v. 45000 Inc  3:04-cr-00180        17
# 5                           USA v. 4628 Group Inc.  5:00-cr-00441         8
# 6                              USA v. 70 North LLC  4:13-po-00001       NaN
# 7                   USA v. 806 TRADING CORPORATION  2:11-cr-00579         8
# 8     USA v. Danny's Management Services LLC et al  2:13-cr-01143       512
# 9     USA v. Danny's Management Services LLC et al  2:13-cr-01143       509
# ...                                            ...            ...       ...
# 3028                     USA v. ZHU & Partners LLC  1:08-cr-00261         7
# 3029                                  USA v. Zavos  5:14-cr-00101        33
# 3030                  USA v. Zein Automobiles Inc.  2:13-cr-00319         7
# 3031                USA v. Zentner & Zentner et al  4:00-cr-40218        11
# 3032                    USA v. Zeon Chemicals L.P.  4:05-cr-00017        15
# 3033                                           NaN            NaN       NaN
# 3034                                           NaN            NaN       NaN
# 3035                    USA v. Zwanger-Pesiri Inc.  2:16-cr-00568       NaN
# 3036                      USA v. E-GOLD LTD. et al  1:07-cr-00109       180
# 3037                              USA v. eAIR, LLC  1:14-cr-20392        14
#
#             DATE JUDGMENT_DATE   PLEA_DATE TICKER US_PUBLIC_CO  \
# 0     2003-06-17    2003-06-17  2003-02-28    NaN           No
# 1     2005-01-25    2005-01-25  2004-09-30    NaN           No
# 2     2014-11-21    2014-11-21  2014-11-20    NaN           No
# 3     2006-07-05    2006-07-05  2006-03-16    NaN           No
# 4     2005-06-03    2005-06-03  2004-11-22    NaN           No
# 5     2001-07-31    2001-07-31  2000-09-20    NaN           No
# 6     2013-03-05    2013-03-05         NaN    NaN           No
# 7     2012-03-05    2012-03-05  2011-09-06    NaN           No
# 8     2014-11-24    2014-11-21  2014-11-20    NaN           No
# 9     2014-11-24    2014-11-21  2014-11-20    NaN           No
# ...          ...           ...         ...    ...          ...
# 3028  2008-09-26    2008-09-26  2008-09-26    NaN           No
# 3029  2015-03-23    2015-03-23  2014-09-11    NaN           No
# 3030  2013-10-23    2013-10-23  2013-10-23    NaN           No
# 3031  2000-11-17    2000-11-17  2000-11-16    NaN           No
# 3032  2005-03-17    2005-03-17  2005-03-16    NaN           No
# 3033  2007-09-01           NaN         NaN    NaN          Yes
# 3034  2015-11-06           NaN         NaN    NaN           No
# 3035  2016-11-21    2016-11-21  2016-11-16    NaN           No
# 3036  2008-12-16    2008-12-16  2008-07-18    NaN           No
# 3037  2014-06-20    2014-06-20  2014-06-20    NaN           No
#
#       ADDITIONAL_REGULATORY_FINE_OR_PAYMENT  COMMUNITY_SERVICE_OR_OTHER  \
# 0                                       NaN                         NaN
# 1                                       NaN                         NaN
# 2                                       0.0                         0.0
# 3                                       NaN                         NaN
# 4                                       NaN                         NaN
# 5                                       0.0                         NaN
# 6                                      35.0                         0.0
# 7                                       0.0                         0.0
# 8                                       0.0                         0.0
# 9                                       0.0                         0.0
# ...                                     ...                         ...
# 3028                                    0.0                         0.0
# 3029                                    0.0                         0.0
# 3030                                  400.0                         0.0
# 3031                                    NaN                         NaN
# 3032                                    NaN                         NaN
# 3033                                    0.0                         NaN
# 3034                                    0.0                         0.0
# 3035                                    NaN                         NaN
# 3036                                    NaN                         NaN
# 3037                                    0.0                         NaN
#
#             FINE  FORFEITURE_DISGORGEMENT  PROBATION_LENGTH  RESTITUTION  \
# 0            0.0                 272734.0              12.0          NaN
# 1        24000.0                      NaN              36.0          NaN
# 2           50.0                      0.0               0.0          0.0
# 3        14640.0                      NaN              36.0          NaN
# 4        25000.0                      NaN               0.0       2500.0
# 5       500000.0                      0.0              24.0          0.0
# 6         2000.0                      0.0               0.0          0.0
# 7        42000.0                      0.0               0.0          0.0
# 8           50.0                      0.0               0.0          0.0
# 9           50.0                      0.0               0.0          0.0
# ...          ...                      ...               ...          ...
# 3028     50000.0                      0.0              60.0          0.0
# 3029    250000.0                      0.0               NaN          0.0
# 3030    250000.0                      0.0              24.0          0.0
# 3031         NaN                      NaN               NaN          NaN
# 3032  10500000.0                      NaN               0.0          NaN
# 3033         0.0                      NaN              18.0          NaN
# 3034   3798000.0                      0.0              48.0          0.0
# 3035         0.0                      0.0              24.0          0.0
# 3036    600000.0                1750000.0              36.0          0.0
# 3037    200000.0                      0.0              60.0          0.0
#
#       TOTAL_PAYMENT ACCEPTS_RESPONSIBILITY  \
# 0            272734                    NaN
# 1             24000                    NaN
# 2                50                    NaN
# 3             14640                    NaN
# 4             27500                    NaN
# 5            500000                    NaN
# 6              2000                    NaN
# 7             42000                    NaN
# 8                50                    NaN
# 9                50                    NaN
# ...             ...                    ...
# 3028          50000                    NaN
# 3029         250000                    NaN
# 3030         250000                    NaN
# 3031              0                    NaN
# 3032       10500000                    NaN
# 3033              0                    Yes
# 3034        3798000                    NaN
# 3035              0                    NaN
# 3036        2350000                    NaN
# 3037         200000                    NaN
#
#                        AGREEMENT_REQUIRED_NEW_POSITIONS  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# ...                                                 ...
# 3028                                                NaN
# 3029                                                NaN
# 3030                                                NaN
# 3031                                                NaN
# 3032                                                NaN
# 3033  Yes; Create Compliance Office, headed by Chief...
# 3034                                                NaN
# 3035                                                NaN
# 3036                                                NaN
# 3037                                                NaN
#
#      AGREEMENT_REQUIRED_OUTSIDE_AUDITORS_OR_EXPERTS CITATION_AND_DESCRIPTION  \
# 0                                               NaN                      NaN
# 1                                               NaN                      NaN
# 2                                               NaN                      NaN
# 3                                               NaN                      NaN
# 4                                               NaN                      NaN
# 5                                               NaN                      NaN
# 6                                               NaN                      NaN
# 7                                               NaN                      NaN
# 8                                               NaN                      NaN
# 9                                               NaN                      NaN
# ...                                             ...                      ...
# 3028                                            NaN                      NaN
# 3029                                            NaN                      NaN
# 3030                                            NaN                      NaN
# 3031                                            NaN                      NaN
# 3032                                            NaN                      NaN
# 3033                                             No                      NaN
# 3034                                            NaN                      NaN
# 3035                                            NaN                      NaN
# 3036                                            NaN                      NaN
# 3037                                            NaN                      NaN
#
#      CIVIL_JUDGMENT_OR_SETTLEMENT  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# 5                             NaN
# 6                             NaN
# 7                             NaN
# 8                             NaN
# 9                             NaN
# ...                           ...
# 3028                          NaN
# 3029                          NaN
# 3030                          NaN
# 3031                          NaN
# 3032                          NaN
# 3033                          NaN
# 3034                          NaN
# 3035                          NaN
# 3036                          NaN
# 3037                          NaN
#
#                          COMPLIANCE_PROGRAM_DESCRIPTION  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# ...                                                 ...
# 3028                                                NaN
# 3029                                                NaN
# 3030                                                NaN
# 3031                                                NaN
# 3032                                                NaN
# 3033  Retain monitor to oversee compliance improvements
# 3034                                                NaN
# 3035                                                NaN
# 3036                                                NaN
# 3037                                                NaN
#
#      COMPLIANCE_PROGRAM_REQUIRED_BY_AGREEMENT  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
# ...                                       ...
# 3028                                      NaN
# 3029                                      NaN
# 3030                                      NaN
# 3031                                      NaN
# 3032                                      NaN
# 3033                                      Yes
# 3034                                      NaN
# 3035                                      NaN
# 3036                                      NaN
# 3037                                      NaN
#
#                     COMPLIANCE_REQUIRED_BY_REGULATORS         CRIME_DESC  \
# 0                                                 NaN                NaN
# 1                                                 NaN                NaN
# 2                                                 NaN                NaN
# 3                                                 NaN                NaN
# 4                                                 NaN                NaN
# 5                                                 NaN                NaN
# 6                                                 NaN                NaN
# 7                                                 NaN                NaN
# 8                                                 NaN                NaN
# 9                                                 NaN                NaN
# ...                                               ...                ...
# 3028                                              NaN                NaN
# 3029                                              NaN                NaN
# 3030                                              NaN                NaN
# 3031                                              NaN                NaN
# 3032                                              NaN                NaN
# 3033  Yes; Corporate Integrity Agreement with OIG-HHS  Anti-Kickback Law
# 3034                                              NaN          Tax fraud
# 3035                                              NaN                NaN
# 3036                                              NaN                NaN
# 3037                                              NaN                NaN
#
#      DESCRIPTION_OF_PAYMENTS  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# ...                      ...
# 3028                     NaN
# 3029                     NaN
# 3030                     NaN
# 3031                     NaN
# 3032                     NaN
# 3033                     NaN
# 3034                     NaN
# 3035                     NaN
# 3036                     NaN
# 3037                     NaN
#
#      DOES_AGREEMENT_DISCUSS_REASONS_OR_RELEVENT_CONSIDERATIONS_FOR_LENIENCY  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# ...                                                 ...
# 3028                                                NaN
# 3029                                                NaN
# 3030                                                NaN
# 3031                                                NaN
# 3032                                                NaN
# 3033  Yes; substantial assistance, enhanced complian...
# 3034                                                NaN
# 3035                                                NaN
# 3036                                                NaN
# 3037                                                NaN
#
#      DOJ_CAN_UNILATERALLY_TERMINATE FINE_CALCULATION_INCLUDED  \
# 0                               NaN                       NaN
# 1                               NaN                       NaN
# 2                               NaN                       NaN
# 3                               NaN                       NaN
# 4                               NaN                       NaN
# 5                               NaN                       NaN
# 6                               NaN                       NaN
# 7                               NaN                       NaN
# 8                               NaN                       NaN
# 9                               NaN                       NaN
# ...                             ...                       ...
# 3028                            NaN                       NaN
# 3029                            NaN                       NaN
# 3030                            NaN                       NaN
# 3031                            NaN                       NaN
# 3032                            NaN                       NaN
# 3033                            Yes                        No
# 3034                            NaN                       NaN
# 3035                            NaN                       NaN
# 3036                            NaN                       NaN
# 3037                            NaN                       NaN
#
#      FINE_DESCRIPTION INDEP_MONITOR_REQUIRED  \
# 0                 NaN                    NaN
# 1                 NaN                    NaN
# 2                 NaN                    NaN
# 3                 NaN                    NaN
# 4                 NaN                    NaN
# 5                 NaN                    NaN
# 6                 NaN                    NaN
# 7                 NaN                    NaN
# 8                 NaN                    NaN
# 9                 NaN                    NaN
# ...               ...                    ...
# 3028              NaN                    NaN
# 3029              NaN                    NaN
# 3030              NaN                    NaN
# 3031              NaN                    NaN
# 3032              NaN                    NaN
# 3033             None                    Yes
# 3034              NaN                    NaN
# 3035              NaN                    NaN
# 3036              NaN                    NaN
# 3037              NaN                    NaN
#
#      MUST_COMPORT_WITH_USSG_OR_AUDIT_COMPLIANCE OTHER_AGREEMENT  \
# 0                                           NaN             NaN
# 1                                           NaN             NaN
# 2                                           NaN             NaN
# 3                                           NaN             NaN
# 4                                           NaN             NaN
# 5                                           NaN             NaN
# 6                                           NaN             NaN
# 7                                           NaN             NaN
# 8                                           NaN             NaN
# 9                                           NaN             NaN
# ...                                         ...             ...
# 3028                                        NaN             NaN
# 3029                                        NaN             NaN
# 3030                                        NaN             NaN
# 3031                                        NaN             NaN
# 3032                                        NaN             NaN
# 3033                                         No             NaN
# 3034                                        NaN             NaN
# 3035                                        NaN             NaN
# 3036                                        NaN             NaN
# 3037                                        NaN             NaN
#
#      OTHER_AGREEMENT_REQUIRED_GOVERNANCE_CHANGES  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
# 9                                            NaN
# ...                                          ...
# 3028                                         NaN
# 3029                                         NaN
# 3030                                         NaN
# 3031                                         NaN
# 3032                                         NaN
# 3033                                          No
# 3034                                         NaN
# 3035                                         NaN
# 3036                                         NaN
# 3037                                         NaN
#
#      OTHER_COMPLIANCE_OFFICER_OR_CONSULTANT_REQUIRED PARALLEL_CIVIL_SUIT  \
# 0                                                NaN                 NaN
# 1                                                NaN                 NaN
# 2                                                NaN                 NaN
# 3                                                NaN                 NaN
# 4                                                NaN                 NaN
# 5                                                NaN                 NaN
# 6                                                NaN                 NaN
# 7                                                NaN                 NaN
# 8                                                NaN                 NaN
# 9                                                NaN                 NaN
# ...                                              ...                 ...
# 3028                                             NaN                 NaN
# 3029                                             NaN                 NaN
# 3030                                             NaN                 NaN
# 3031                                             NaN                 NaN
# 3032                                             NaN                 NaN
# 3033                                             Yes                  No
# 3034                                             NaN                 NaN
# 3035                                             NaN                 NaN
# 3036                                             NaN                 NaN
# 3037                                             NaN                 NaN
#
#      PARALLEL_REGULATORY_ACTION_OR_LOCAL_PROSECUTOR PRE_AGREEMENT_COMPLIANCE  \
# 0                                               NaN                      NaN
# 1                                               NaN                      NaN
# 2                                               NaN                      NaN
# 3                                               NaN                      NaN
# 4                                               NaN                      NaN
# 5                                               NaN                      NaN
# 6                                               NaN                      NaN
# 7                                               NaN                      NaN
# 8                                               NaN                      NaN
# 9                                               NaN                      NaN
# ...                                             ...                      ...
# 3028                                            NaN                      NaN
# 3029                                            NaN                      NaN
# 3030                                            NaN                      NaN
# 3031                                            NaN                      NaN
# 3032                                            NaN                      NaN
# 3033                                   Yes; HHS-OIG                      Yes
# 3034                                            NaN                      NaN
# 3035                                            NaN                      NaN
# 3036                                            NaN                      NaN
# 3037                                            NaN                      NaN
#
#                    PRE_AGREEMENT_COMPLIANCE_DESCRIPTION PRIVACY_WAIVER  \
# 0                                                   NaN            NaN
# 1                                                   NaN            NaN
# 2                                                   NaN            NaN
# 3                                                   NaN            NaN
# 4                                                   NaN            NaN
# 5                                                   NaN            NaN
# 6                                                   NaN            NaN
# 7                                                   NaN            NaN
# 8                                                   NaN            NaN
# 9                                                   NaN            NaN
# ...                                                 ...            ...
# 3028                                                NaN            NaN
# 3029                                                NaN            NaN
# 3030                                                NaN            NaN
# 3031                                                NaN            NaN
# 3032                                                NaN            NaN
# 3033  Yes; Appointing Chief Compliance Officer, new ...             No
# 3034                                                NaN            NaN
# 3035                                                NaN            NaN
# 3036                                                NaN            NaN
# 3037                                                NaN            NaN
#
#       REGULATORY_DISGORGEMENT_RESTITUTION_FORFEITURE  REGULATORY_FINE  \
# 0                                                NaN              NaN
# 1                                                NaN              NaN
# 2                                                NaN              NaN
# 3                                                NaN              NaN
# 4                                                NaN              NaN
# 5                                                NaN              NaN
# 6                                                NaN              NaN
# 7                                                NaN              NaN
# 8                                                NaN              NaN
# 9                                                NaN              NaN
# ...                                              ...              ...
# 3028                                             NaN              NaN
# 3029                                             NaN              NaN
# 3030                                             NaN              NaN
# 3031                                             NaN              NaN
# 3032                                             NaN              NaN
# 3033                                             0.0      196500000.0
# 3034                                             NaN              NaN
# 3035                                             NaN              NaN
# 3036                                             NaN              NaN
# 3037                                             NaN              NaN
#
#                                              REG_AGENCY STATEMENT_OF_FACTS  \
# 0                                                   NaN                NaN
# 1                                                   NaN                NaN
# 2                                                   NaN                NaN
# 3                                                   NaN                NaN
# 4                                                   NaN                NaN
# 5                                                   NaN                NaN
# 6                                                   NaN                NaN
# 7                                                   NaN                NaN
# 8                                                   NaN                NaN
# 9                                                   NaN                NaN
# ...                                                 ...                ...
# 3028                                                NaN                NaN
# 3029                                                NaN                NaN
# 3030                                                NaN                NaN
# 3031                                                NaN                NaN
# 3032                                                NaN                NaN
# 3033  Dept. of Health & Human Services; U.S. Postal ...                Yes
# 3034                                                NaN                NaN
# 3035                                                NaN                NaN
# 3036                                                NaN                NaN
# 3037                                                NaN                NaN
#
#       TOTAL_REGULATORY UNRELATED_TERMS  AGMT_YEAR  \
# 0                  NaN             NaN     2003.0
# 1                  NaN             NaN     2005.0
# 2                  NaN             NaN     2014.0
# 3                  NaN             NaN     2006.0
# 4                  NaN             NaN     2005.0
# 5                  NaN             NaN     2001.0
# 6                  NaN             NaN     2013.0
# 7                  NaN             NaN     2012.0
# 8                  NaN             NaN     2014.0
# 9                  NaN             NaN     2014.0
# ...                ...             ...        ...
# 3028               NaN             NaN     2008.0
# 3029               NaN             NaN     2015.0
# 3030               NaN             NaN     2013.0
# 3031               NaN             NaN     2000.0
# 3032               NaN             NaN     2005.0
# 3033       196500000.0              No     2007.0
# 3034               NaN             NaN     2015.0
# 3035               NaN             NaN     2016.0
# 3036               NaN             NaN     2008.0
# 3037               NaN             NaN     2014.0
#
#                                                  SOURCE NOTES
# 0                                                 PACER   NaN
# 1                                                 PACER   NaN
# 2                                                 PACER   NaN
# 3                                                 PACER   NaN
# 4                                                 PACER   NaN
# 5                                                 PACER   NaN
# 6                                                 PACER   NaN
# 7                                                 PACER   NaN
# 8                                                 PACER   NaN
# 9                                                 PACER   NaN
# ...                                                 ...   ...
# 3028                                              PACER   NaN
# 3029                                              PACER   NaN
# 3030                                              PACER   NaN
# 3031                                              PACER   NaN
# 3032                                              PACER   NaN
# 3033                                                NaN   NaN
# 3034  USDOJ - Tax Division - Swiss Bank Program (see...   NaN
# 3035                                              PACER   NaN
# 3036                                              PACER   NaN
# 3037                                              PACER   NaN
#
# [3038 rows x 56 columns]

# %% [markdown]
# ## How do you see the number of rows pandas will display? Then, set it to display 100 rows at a time.
#
# What does "the number rows pandas will display" actually mean?

# %%
pd.set_option('display.max_rows', 20)
df
# Out:
#       REC_ID                                 COMPANY DISPOSITION_TYPE  \
# 0        138  1st Union Transfer and Telegraph, Inc.             plea
# 1        139                3D Poultry Loading, Inc.             plea
# 2       2529                         3rd & Bell, LLC             plea
# 3        822                          41 Market Inc.             plea
# 4        140                            45,000, Inc.             plea
# 5        823                         4628 Group Inc.             plea
# 6        824                           70 North, LLC             plea
# 7        825                       806 Trading Corp.             plea
# 8       2530                 83rd & Union Hills, LLC             plea
# 9       2531                        84th & Bell, LLC             plea
# ...      ...                                     ...              ...
# 3028    2516                      ZHU & Partners LLC             plea
# 3029    2711     Zavos Diagnostic Laboratories, Inc.             plea
# 3030    2517                   Zein Automobiles Inc.             plea
# 3031    2923                       Zentner & Zentner             plea
# 3032    2518                          Zeon Chemicals             plea
# 3033    2523                   Zimmer Holdings, Inc.               DP
# 3034     136                      Zuger Kantonalbank               NP
# 3035    3077                     Zwanger-Pesiri Inc.             plea
# 3036     253                             e-gold Ltd.             plea
# 3037    2585                               eAir, LLC             plea
#
#                             PRIMARY_CRIME_CODE SWISS_BANK_PROGRAM  \
# 0                             Money Laundering                NaN
# 1                                  Immigration                NaN
# 2                                  Immigration                NaN
# 3     Controlled substances / Drugs / Meth Act                NaN
# 4                                Environmental                NaN
# 5                                Environmental                NaN
# 6                                Environmental                NaN
# 7                                        Other                NaN
# 8                                  Immigration                NaN
# 9                                  Immigration                NaN
# ...                                        ...                ...
# 3028                               Immigration                NaN
# 3029                                     Other                NaN
# 3030                        Fraud - Accounting                NaN
# 3031                                  Wildlife                NaN
# 3032                                 Antitrust                NaN
# 3033                                 Kickbacks                 No
# 3034                               Fraud - Tax                Yes
# 3035                       Fraud - Health Care                NaN
# 3036                          Money Laundering                NaN
# 3037                             Environmental                NaN
#
#                                                    USAO  \
# 0                           Virginia - Eastern District
# 1                           Arkansas - Western District
# 2                                               Arizona
# 3                           Georgia - Northern District
# 4                           Louisiana - Middle District
# 5                          New York - Northern District
# 6                                                Alaska
# 7                                            New Jersey
# 8                                               Arizona
# 9                                               Arizona
# ...                                                 ...
# 3028                                           Maryland
# 3029                        Kentucky - Eastern District
# 3030                      Washington - Western District
# 3031  USDOJ - Environment & Natural Resources Divisi...
# 3032                         USDOJ - Antitrust Division
# 3033                                         New Jersey
# 3034                               USDOJ - Tax Division
# 3035                        New York - Eastern District
# 3036  District of Columbia,USDOJ - Criminal Division...
# 3037                        Florida - Southern District
#
#                     COUNTRY FINANCIAL_INSTITUTION  \
# 0             United States                   Yes
# 1             United States                    No
# 2             United States                    No
# 3             United States                    No
# 4             United States                    No
# 5             United States                    No
# 6             United States                    No
# 7             United States                    No
# 8             United States                    No
# 9             United States                    No
# ...                     ...                   ...
# 3028          United States                    No
# 3029          United States                    No
# 3030          United States                    No
# 3031          United States                    No
# 3032          United States                    No
# 3033          United States                    No
# 3034            Switzerland                   Yes
# 3035          United States                    No
# 3036  Saint Kitts and Nevis                   Yes
# 3037          United States                    No
#
#                                          CASE_NAME        CASE_ID DOCKET_NO  \
# 0                        USA v. 1st Union Transfer  4:03-cr-00024         8
# 1                        USA v. 3D Poultry Loading  2:04-cr-20061         7
# 2     USA v. Danny's Management Services LLC et al  2:13-cr-01143       510
# 3                            USA v. 41 Market Inc.  4:06-cr-00023        11
# 4                                 USA v. 45000 Inc  3:04-cr-00180        17
# 5                           USA v. 4628 Group Inc.  5:00-cr-00441         8
# 6                              USA v. 70 North LLC  4:13-po-00001       NaN
# 7                   USA v. 806 TRADING CORPORATION  2:11-cr-00579         8
# 8     USA v. Danny's Management Services LLC et al  2:13-cr-01143       512
# 9     USA v. Danny's Management Services LLC et al  2:13-cr-01143       509
# ...                                            ...            ...       ...
# 3028                     USA v. ZHU & Partners LLC  1:08-cr-00261         7
# 3029                                  USA v. Zavos  5:14-cr-00101        33
# 3030                  USA v. Zein Automobiles Inc.  2:13-cr-00319         7
# 3031                USA v. Zentner & Zentner et al  4:00-cr-40218        11
# 3032                    USA v. Zeon Chemicals L.P.  4:05-cr-00017        15
# 3033                                           NaN            NaN       NaN
# 3034                                           NaN            NaN       NaN
# 3035                    USA v. Zwanger-Pesiri Inc.  2:16-cr-00568       NaN
# 3036                      USA v. E-GOLD LTD. et al  1:07-cr-00109       180
# 3037                              USA v. eAIR, LLC  1:14-cr-20392        14
#
#             DATE JUDGMENT_DATE   PLEA_DATE TICKER US_PUBLIC_CO  \
# 0     2003-06-17    2003-06-17  2003-02-28    NaN           No
# 1     2005-01-25    2005-01-25  2004-09-30    NaN           No
# 2     2014-11-21    2014-11-21  2014-11-20    NaN           No
# 3     2006-07-05    2006-07-05  2006-03-16    NaN           No
# 4     2005-06-03    2005-06-03  2004-11-22    NaN           No
# 5     2001-07-31    2001-07-31  2000-09-20    NaN           No
# 6     2013-03-05    2013-03-05         NaN    NaN           No
# 7     2012-03-05    2012-03-05  2011-09-06    NaN           No
# 8     2014-11-24    2014-11-21  2014-11-20    NaN           No
# 9     2014-11-24    2014-11-21  2014-11-20    NaN           No
# ...          ...           ...         ...    ...          ...
# 3028  2008-09-26    2008-09-26  2008-09-26    NaN           No
# 3029  2015-03-23    2015-03-23  2014-09-11    NaN           No
# 3030  2013-10-23    2013-10-23  2013-10-23    NaN           No
# 3031  2000-11-17    2000-11-17  2000-11-16    NaN           No
# 3032  2005-03-17    2005-03-17  2005-03-16    NaN           No
# 3033  2007-09-01           NaN         NaN    NaN          Yes
# 3034  2015-11-06           NaN         NaN    NaN           No
# 3035  2016-11-21    2016-11-21  2016-11-16    NaN           No
# 3036  2008-12-16    2008-12-16  2008-07-18    NaN           No
# 3037  2014-06-20    2014-06-20  2014-06-20    NaN           No
#
#       ADDITIONAL_REGULATORY_FINE_OR_PAYMENT  COMMUNITY_SERVICE_OR_OTHER  \
# 0                                       NaN                         NaN
# 1                                       NaN                         NaN
# 2                                       0.0                         0.0
# 3                                       NaN                         NaN
# 4                                       NaN                         NaN
# 5                                       0.0                         NaN
# 6                                      35.0                         0.0
# 7                                       0.0                         0.0
# 8                                       0.0                         0.0
# 9                                       0.0                         0.0
# ...                                     ...                         ...
# 3028                                    0.0                         0.0
# 3029                                    0.0                         0.0
# 3030                                  400.0                         0.0
# 3031                                    NaN                         NaN
# 3032                                    NaN                         NaN
# 3033                                    0.0                         NaN
# 3034                                    0.0                         0.0
# 3035                                    NaN                         NaN
# 3036                                    NaN                         NaN
# 3037                                    0.0                         NaN
#
#             FINE  FORFEITURE_DISGORGEMENT  PROBATION_LENGTH  RESTITUTION  \
# 0            0.0                 272734.0              12.0          NaN
# 1        24000.0                      NaN              36.0          NaN
# 2           50.0                      0.0               0.0          0.0
# 3        14640.0                      NaN              36.0          NaN
# 4        25000.0                      NaN               0.0       2500.0
# 5       500000.0                      0.0              24.0          0.0
# 6         2000.0                      0.0               0.0          0.0
# 7        42000.0                      0.0               0.0          0.0
# 8           50.0                      0.0               0.0          0.0
# 9           50.0                      0.0               0.0          0.0
# ...          ...                      ...               ...          ...
# 3028     50000.0                      0.0              60.0          0.0
# 3029    250000.0                      0.0               NaN          0.0
# 3030    250000.0                      0.0              24.0          0.0
# 3031         NaN                      NaN               NaN          NaN
# 3032  10500000.0                      NaN               0.0          NaN
# 3033         0.0                      NaN              18.0          NaN
# 3034   3798000.0                      0.0              48.0          0.0
# 3035         0.0                      0.0              24.0          0.0
# 3036    600000.0                1750000.0              36.0          0.0
# 3037    200000.0                      0.0              60.0          0.0
#
#       TOTAL_PAYMENT ACCEPTS_RESPONSIBILITY  \
# 0            272734                    NaN
# 1             24000                    NaN
# 2                50                    NaN
# 3             14640                    NaN
# 4             27500                    NaN
# 5            500000                    NaN
# 6              2000                    NaN
# 7             42000                    NaN
# 8                50                    NaN
# 9                50                    NaN
# ...             ...                    ...
# 3028          50000                    NaN
# 3029         250000                    NaN
# 3030         250000                    NaN
# 3031              0                    NaN
# 3032       10500000                    NaN
# 3033              0                    Yes
# 3034        3798000                    NaN
# 3035              0                    NaN
# 3036        2350000                    NaN
# 3037         200000                    NaN
#
#                        AGREEMENT_REQUIRED_NEW_POSITIONS  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# ...                                                 ...
# 3028                                                NaN
# 3029                                                NaN
# 3030                                                NaN
# 3031                                                NaN
# 3032                                                NaN
# 3033  Yes; Create Compliance Office, headed by Chief...
# 3034                                                NaN
# 3035                                                NaN
# 3036                                                NaN
# 3037                                                NaN
#
#      AGREEMENT_REQUIRED_OUTSIDE_AUDITORS_OR_EXPERTS CITATION_AND_DESCRIPTION  \
# 0                                               NaN                      NaN
# 1                                               NaN                      NaN
# 2                                               NaN                      NaN
# 3                                               NaN                      NaN
# 4                                               NaN                      NaN
# 5                                               NaN                      NaN
# 6                                               NaN                      NaN
# 7                                               NaN                      NaN
# 8                                               NaN                      NaN
# 9                                               NaN                      NaN
# ...                                             ...                      ...
# 3028                                            NaN                      NaN
# 3029                                            NaN                      NaN
# 3030                                            NaN                      NaN
# 3031                                            NaN                      NaN
# 3032                                            NaN                      NaN
# 3033                                             No                      NaN
# 3034                                            NaN                      NaN
# 3035                                            NaN                      NaN
# 3036                                            NaN                      NaN
# 3037                                            NaN                      NaN
#
#      CIVIL_JUDGMENT_OR_SETTLEMENT  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# 5                             NaN
# 6                             NaN
# 7                             NaN
# 8                             NaN
# 9                             NaN
# ...                           ...
# 3028                          NaN
# 3029                          NaN
# 3030                          NaN
# 3031                          NaN
# 3032                          NaN
# 3033                          NaN
# 3034                          NaN
# 3035                          NaN
# 3036                          NaN
# 3037                          NaN
#
#                          COMPLIANCE_PROGRAM_DESCRIPTION  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# ...                                                 ...
# 3028                                                NaN
# 3029                                                NaN
# 3030                                                NaN
# 3031                                                NaN
# 3032                                                NaN
# 3033  Retain monitor to oversee compliance improvements
# 3034                                                NaN
# 3035                                                NaN
# 3036                                                NaN
# 3037                                                NaN
#
#      COMPLIANCE_PROGRAM_REQUIRED_BY_AGREEMENT  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
# ...                                       ...
# 3028                                      NaN
# 3029                                      NaN
# 3030                                      NaN
# 3031                                      NaN
# 3032                                      NaN
# 3033                                      Yes
# 3034                                      NaN
# 3035                                      NaN
# 3036                                      NaN
# 3037                                      NaN
#
#                     COMPLIANCE_REQUIRED_BY_REGULATORS         CRIME_DESC  \
# 0                                                 NaN                NaN
# 1                                                 NaN                NaN
# 2                                                 NaN                NaN
# 3                                                 NaN                NaN
# 4                                                 NaN                NaN
# 5                                                 NaN                NaN
# 6                                                 NaN                NaN
# 7                                                 NaN                NaN
# 8                                                 NaN                NaN
# 9                                                 NaN                NaN
# ...                                               ...                ...
# 3028                                              NaN                NaN
# 3029                                              NaN                NaN
# 3030                                              NaN                NaN
# 3031                                              NaN                NaN
# 3032                                              NaN                NaN
# 3033  Yes; Corporate Integrity Agreement with OIG-HHS  Anti-Kickback Law
# 3034                                              NaN          Tax fraud
# 3035                                              NaN                NaN
# 3036                                              NaN                NaN
# 3037                                              NaN                NaN
#
#      DESCRIPTION_OF_PAYMENTS  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# ...                      ...
# 3028                     NaN
# 3029                     NaN
# 3030                     NaN
# 3031                     NaN
# 3032                     NaN
# 3033                     NaN
# 3034                     NaN
# 3035                     NaN
# 3036                     NaN
# 3037                     NaN
#
#      DOES_AGREEMENT_DISCUSS_REASONS_OR_RELEVENT_CONSIDERATIONS_FOR_LENIENCY  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# ...                                                 ...
# 3028                                                NaN
# 3029                                                NaN
# 3030                                                NaN
# 3031                                                NaN
# 3032                                                NaN
# 3033  Yes; substantial assistance, enhanced complian...
# 3034                                                NaN
# 3035                                                NaN
# 3036                                                NaN
# 3037                                                NaN
#
#      DOJ_CAN_UNILATERALLY_TERMINATE FINE_CALCULATION_INCLUDED  \
# 0                               NaN                       NaN
# 1                               NaN                       NaN
# 2                               NaN                       NaN
# 3                               NaN                       NaN
# 4                               NaN                       NaN
# 5                               NaN                       NaN
# 6                               NaN                       NaN
# 7                               NaN                       NaN
# 8                               NaN                       NaN
# 9                               NaN                       NaN
# ...                             ...                       ...
# 3028                            NaN                       NaN
# 3029                            NaN                       NaN
# 3030                            NaN                       NaN
# 3031                            NaN                       NaN
# 3032                            NaN                       NaN
# 3033                            Yes                        No
# 3034                            NaN                       NaN
# 3035                            NaN                       NaN
# 3036                            NaN                       NaN
# 3037                            NaN                       NaN
#
#      FINE_DESCRIPTION INDEP_MONITOR_REQUIRED  \
# 0                 NaN                    NaN
# 1                 NaN                    NaN
# 2                 NaN                    NaN
# 3                 NaN                    NaN
# 4                 NaN                    NaN
# 5                 NaN                    NaN
# 6                 NaN                    NaN
# 7                 NaN                    NaN
# 8                 NaN                    NaN
# 9                 NaN                    NaN
# ...               ...                    ...
# 3028              NaN                    NaN
# 3029              NaN                    NaN
# 3030              NaN                    NaN
# 3031              NaN                    NaN
# 3032              NaN                    NaN
# 3033             None                    Yes
# 3034              NaN                    NaN
# 3035              NaN                    NaN
# 3036              NaN                    NaN
# 3037              NaN                    NaN
#
#      MUST_COMPORT_WITH_USSG_OR_AUDIT_COMPLIANCE OTHER_AGREEMENT  \
# 0                                           NaN             NaN
# 1                                           NaN             NaN
# 2                                           NaN             NaN
# 3                                           NaN             NaN
# 4                                           NaN             NaN
# 5                                           NaN             NaN
# 6                                           NaN             NaN
# 7                                           NaN             NaN
# 8                                           NaN             NaN
# 9                                           NaN             NaN
# ...                                         ...             ...
# 3028                                        NaN             NaN
# 3029                                        NaN             NaN
# 3030                                        NaN             NaN
# 3031                                        NaN             NaN
# 3032                                        NaN             NaN
# 3033                                         No             NaN
# 3034                                        NaN             NaN
# 3035                                        NaN             NaN
# 3036                                        NaN             NaN
# 3037                                        NaN             NaN
#
#      OTHER_AGREEMENT_REQUIRED_GOVERNANCE_CHANGES  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
# 9                                            NaN
# ...                                          ...
# 3028                                         NaN
# 3029                                         NaN
# 3030                                         NaN
# 3031                                         NaN
# 3032                                         NaN
# 3033                                          No
# 3034                                         NaN
# 3035                                         NaN
# 3036                                         NaN
# 3037                                         NaN
#
#      OTHER_COMPLIANCE_OFFICER_OR_CONSULTANT_REQUIRED PARALLEL_CIVIL_SUIT  \
# 0                                                NaN                 NaN
# 1                                                NaN                 NaN
# 2                                                NaN                 NaN
# 3                                                NaN                 NaN
# 4                                                NaN                 NaN
# 5                                                NaN                 NaN
# 6                                                NaN                 NaN
# 7                                                NaN                 NaN
# 8                                                NaN                 NaN
# 9                                                NaN                 NaN
# ...                                              ...                 ...
# 3028                                             NaN                 NaN
# 3029                                             NaN                 NaN
# 3030                                             NaN                 NaN
# 3031                                             NaN                 NaN
# 3032                                             NaN                 NaN
# 3033                                             Yes                  No
# 3034                                             NaN                 NaN
# 3035                                             NaN                 NaN
# 3036                                             NaN                 NaN
# 3037                                             NaN                 NaN
#
#      PARALLEL_REGULATORY_ACTION_OR_LOCAL_PROSECUTOR PRE_AGREEMENT_COMPLIANCE  \
# 0                                               NaN                      NaN
# 1                                               NaN                      NaN
# 2                                               NaN                      NaN
# 3                                               NaN                      NaN
# 4                                               NaN                      NaN
# 5                                               NaN                      NaN
# 6                                               NaN                      NaN
# 7                                               NaN                      NaN
# 8                                               NaN                      NaN
# 9                                               NaN                      NaN
# ...                                             ...                      ...
# 3028                                            NaN                      NaN
# 3029                                            NaN                      NaN
# 3030                                            NaN                      NaN
# 3031                                            NaN                      NaN
# 3032                                            NaN                      NaN
# 3033                                   Yes; HHS-OIG                      Yes
# 3034                                            NaN                      NaN
# 3035                                            NaN                      NaN
# 3036                                            NaN                      NaN
# 3037                                            NaN                      NaN
#
#                    PRE_AGREEMENT_COMPLIANCE_DESCRIPTION PRIVACY_WAIVER  \
# 0                                                   NaN            NaN
# 1                                                   NaN            NaN
# 2                                                   NaN            NaN
# 3                                                   NaN            NaN
# 4                                                   NaN            NaN
# 5                                                   NaN            NaN
# 6                                                   NaN            NaN
# 7                                                   NaN            NaN
# 8                                                   NaN            NaN
# 9                                                   NaN            NaN
# ...                                                 ...            ...
# 3028                                                NaN            NaN
# 3029                                                NaN            NaN
# 3030                                                NaN            NaN
# 3031                                                NaN            NaN
# 3032                                                NaN            NaN
# 3033  Yes; Appointing Chief Compliance Officer, new ...             No
# 3034                                                NaN            NaN
# 3035                                                NaN            NaN
# 3036                                                NaN            NaN
# 3037                                                NaN            NaN
#
#       REGULATORY_DISGORGEMENT_RESTITUTION_FORFEITURE  REGULATORY_FINE  \
# 0                                                NaN              NaN
# 1                                                NaN              NaN
# 2                                                NaN              NaN
# 3                                                NaN              NaN
# 4                                                NaN              NaN
# 5                                                NaN              NaN
# 6                                                NaN              NaN
# 7                                                NaN              NaN
# 8                                                NaN              NaN
# 9                                                NaN              NaN
# ...                                              ...              ...
# 3028                                             NaN              NaN
# 3029                                             NaN              NaN
# 3030                                             NaN              NaN
# 3031                                             NaN              NaN
# 3032                                             NaN              NaN
# 3033                                             0.0      196500000.0
# 3034                                             NaN              NaN
# 3035                                             NaN              NaN
# 3036                                             NaN              NaN
# 3037                                             NaN              NaN
#
#                                              REG_AGENCY STATEMENT_OF_FACTS  \
# 0                                                   NaN                NaN
# 1                                                   NaN                NaN
# 2                                                   NaN                NaN
# 3                                                   NaN                NaN
# 4                                                   NaN                NaN
# 5                                                   NaN                NaN
# 6                                                   NaN                NaN
# 7                                                   NaN                NaN
# 8                                                   NaN                NaN
# 9                                                   NaN                NaN
# ...                                                 ...                ...
# 3028                                                NaN                NaN
# 3029                                                NaN                NaN
# 3030                                                NaN                NaN
# 3031                                                NaN                NaN
# 3032                                                NaN                NaN
# 3033  Dept. of Health & Human Services; U.S. Postal ...                Yes
# 3034                                                NaN                NaN
# 3035                                                NaN                NaN
# 3036                                                NaN                NaN
# 3037                                                NaN                NaN
#
#       TOTAL_REGULATORY UNRELATED_TERMS  AGMT_YEAR  \
# 0                  NaN             NaN     2003.0
# 1                  NaN             NaN     2005.0
# 2                  NaN             NaN     2014.0
# 3                  NaN             NaN     2006.0
# 4                  NaN             NaN     2005.0
# 5                  NaN             NaN     2001.0
# 6                  NaN             NaN     2013.0
# 7                  NaN             NaN     2012.0
# 8                  NaN             NaN     2014.0
# 9                  NaN             NaN     2014.0
# ...                ...             ...        ...
# 3028               NaN             NaN     2008.0
# 3029               NaN             NaN     2015.0
# 3030               NaN             NaN     2013.0
# 3031               NaN             NaN     2000.0
# 3032               NaN             NaN     2005.0
# 3033       196500000.0              No     2007.0
# 3034               NaN             NaN     2015.0
# 3035               NaN             NaN     2016.0
# 3036               NaN             NaN     2008.0
# 3037               NaN             NaN     2014.0
#
#                                                  SOURCE NOTES
# 0                                                 PACER   NaN
# 1                                                 PACER   NaN
# 2                                                 PACER   NaN
# 3                                                 PACER   NaN
# 4                                                 PACER   NaN
# 5                                                 PACER   NaN
# 6                                                 PACER   NaN
# 7                                                 PACER   NaN
# 8                                                 PACER   NaN
# 9                                                 PACER   NaN
# ...                                                 ...   ...
# 3028                                              PACER   NaN
# 3029                                              PACER   NaN
# 3030                                              PACER   NaN
# 3031                                              PACER   NaN
# 3032                                              PACER   NaN
# 3033                                                NaN   NaN
# 3034  USDOJ - Tax Division - Swiss Bank Program (see...   NaN
# 3035                                              PACER   NaN
# 3036                                              PACER   NaN
# 3037                                              PACER   NaN
#
# [3038 rows x 56 columns]

# %% [markdown]
# ## Describe the TOTAL_PAYMENT column to me numerically - maxes, mins, averages.
#
# Do this in **one line.**

# %%
df['TOTAL_PAYMENT'].describe()
# Out:
# count    3.038000e+03
# mean     2.284273e+07
# std      1.556977e+08
# min      0.000000e+00
# 25%      2.189200e+04
# 50%      2.000000e+05
# 75%      2.100000e+06
# max      4.486800e+09
# Name: TOTAL_PAYMENT, dtype: float64

# %% [markdown]
# ### Oh that's ugly ugly ugly. Set pandas to format floats with 2 decimal points, we probably don't need to be more specific than that. Oh, and tell it to use a `,` in the thousands position!
#
# I'm just going to leave [this here](http://infohost.nmt.edu/~shipman/doc/python27/web/new-str-format.html) for reference. You should definitely come up and ask on the board, though.

# %%
df['TOTAL_PAYMENT'].describe().astype(int)
# Out:
# count          3038
# mean       22842732
# std       155697740
# min               0
# 25%           21892
# 50%          200000
# 75%         2100000
# max      4486800000
# Name: TOTAL_PAYMENT, dtype: int64

# %% [markdown]
# ## Look at the fine and the forfeiture disgorgement for the first two rows. Pretty nice!

# %%
df.columns
# Out:
# Index(['REC_ID', 'COMPANY', 'DISPOSITION_TYPE', 'PRIMARY_CRIME_CODE',
#        'SWISS_BANK_PROGRAM', 'USAO', 'COUNTRY', 'FINANCIAL_INSTITUTION',
#        'CASE_NAME', 'CASE_ID', 'DOCKET_NO', 'DATE', 'JUDGMENT_DATE',
#        'PLEA_DATE', 'TICKER', 'US_PUBLIC_CO',
#        'ADDITIONAL_REGULATORY_FINE_OR_PAYMENT', 'COMMUNITY_SERVICE_OR_OTHER',
#        'FINE', 'FORFEITURE_DISGORGEMENT', 'PROBATION_LENGTH', 'RESTITUTION',
#        'TOTAL_PAYMENT', 'ACCEPTS_RESPONSIBILITY',
#        'AGREEMENT_REQUIRED_NEW_POSITIONS',
#        'AGREEMENT_REQUIRED_OUTSIDE_AUDITORS_OR_EXPERTS',
#        'CITATION_AND_DESCRIPTION', 'CIVIL_JUDGMENT_OR_SETTLEMENT',
#        'COMPLIANCE_PROGRAM_DESCRIPTION',
#        'COMPLIANCE_PROGRAM_REQUIRED_BY_AGREEMENT',
#        'COMPLIANCE_REQUIRED_BY_REGULATORS', 'CRIME_DESC',
#        'DESCRIPTION_OF_PAYMENTS',
#        'DOES_AGREEMENT_DISCUSS_REASONS_OR_RELEVENT_CONSIDERATIONS_FOR_LENIENCY',
#        'DOJ_CAN_UNILATERALLY_TERMINATE', 'FINE_CALCULATION_INCLUDED',
#        'FINE_DESCRIPTION', 'INDEP_MONITOR_REQUIRED',
#        'MUST_COMPORT_WITH_USSG_OR_AUDIT_COMPLIANCE', 'OTHER_AGREEMENT',
#        'OTHER_AGREEMENT_REQUIRED_GOVERNANCE_CHANGES',
#        'OTHER_COMPLIANCE_OFFICER_OR_CONSULTANT_REQUIRED',
#        'PARALLEL_CIVIL_SUIT', 'PARALLEL_REGULATORY_ACTION_OR_LOCAL_PROSECUTOR',
#        'PRE_AGREEMENT_COMPLIANCE', 'PRE_AGREEMENT_COMPLIANCE_DESCRIPTION',
#        'PRIVACY_WAIVER', 'REGULATORY_DISGORGEMENT_RESTITUTION_FORFEITURE',
#        'REGULATORY_FINE', 'REG_AGENCY', 'STATEMENT_OF_FACTS',
#        'TOTAL_REGULATORY', 'UNRELATED_TERMS', 'AGMT_YEAR', 'SOURCE', 'NOTES'],
#       dtype='object')

# %%
df.head(5)
# Out:
#    REC_ID                                 COMPANY DISPOSITION_TYPE  \
# 0     138  1st Union Transfer and Telegraph, Inc.             plea
# 1     139                3D Poultry Loading, Inc.             plea
# 2    2529                         3rd & Bell, LLC             plea
# 3     822                          41 Market Inc.             plea
# 4     140                            45,000, Inc.             plea
#
#                          PRIMARY_CRIME_CODE SWISS_BANK_PROGRAM  \
# 0                          Money Laundering                NaN
# 1                               Immigration                NaN
# 2                               Immigration                NaN
# 3  Controlled substances / Drugs / Meth Act                NaN
# 4                             Environmental                NaN
#
#                           USAO        COUNTRY FINANCIAL_INSTITUTION  \
# 0  Virginia - Eastern District  United States                   Yes
# 1  Arkansas - Western District  United States                    No
# 2                      Arizona  United States                    No
# 3  Georgia - Northern District  United States                    No
# 4  Louisiana - Middle District  United States                    No
#
#                                       CASE_NAME        CASE_ID DOCKET_NO  \
# 0                     USA v. 1st Union Transfer  4:03-cr-00024         8
# 1                     USA v. 3D Poultry Loading  2:04-cr-20061         7
# 2  USA v. Danny's Management Services LLC et al  2:13-cr-01143       510
# 3                         USA v. 41 Market Inc.  4:06-cr-00023        11
# 4                              USA v. 45000 Inc  3:04-cr-00180        17
#
#          DATE JUDGMENT_DATE   PLEA_DATE TICKER US_PUBLIC_CO  \
# 0  2003-06-17    2003-06-17  2003-02-28    NaN           No
# 1  2005-01-25    2005-01-25  2004-09-30    NaN           No
# 2  2014-11-21    2014-11-21  2014-11-20    NaN           No
# 3  2006-07-05    2006-07-05  2006-03-16    NaN           No
# 4  2005-06-03    2005-06-03  2004-11-22    NaN           No
#
#    ADDITIONAL_REGULATORY_FINE_OR_PAYMENT  COMMUNITY_SERVICE_OR_OTHER     FINE  \
# 0                                    NaN                         NaN      0.0
# 1                                    NaN                         NaN  24000.0
# 2                                    0.0                         0.0     50.0
# 3                                    NaN                         NaN  14640.0
# 4                                    NaN                         NaN  25000.0
#
#    FORFEITURE_DISGORGEMENT  PROBATION_LENGTH  RESTITUTION  TOTAL_PAYMENT  \
# 0                 272734.0              12.0          NaN         272734
# 1                      NaN              36.0          NaN          24000
# 2                      0.0               0.0          0.0             50
# 3                      NaN              36.0          NaN          14640
# 4                      NaN               0.0       2500.0          27500
#
#   ACCEPTS_RESPONSIBILITY AGREEMENT_REQUIRED_NEW_POSITIONS  \
# 0                    NaN                              NaN
# 1                    NaN                              NaN
# 2                    NaN                              NaN
# 3                    NaN                              NaN
# 4                    NaN                              NaN
#
#   AGREEMENT_REQUIRED_OUTSIDE_AUDITORS_OR_EXPERTS CITATION_AND_DESCRIPTION  \
# 0                                            NaN                      NaN
# 1                                            NaN                      NaN
# 2                                            NaN                      NaN
# 3                                            NaN                      NaN
# 4                                            NaN                      NaN
#
#   CIVIL_JUDGMENT_OR_SETTLEMENT COMPLIANCE_PROGRAM_DESCRIPTION  \
# 0                          NaN                            NaN
# 1                          NaN                            NaN
# 2                          NaN                            NaN
# 3                          NaN                            NaN
# 4                          NaN                            NaN
#
#   COMPLIANCE_PROGRAM_REQUIRED_BY_AGREEMENT COMPLIANCE_REQUIRED_BY_REGULATORS  \
# 0                                      NaN                               NaN
# 1                                      NaN                               NaN
# 2                                      NaN                               NaN
# 3                                      NaN                               NaN
# 4                                      NaN                               NaN
#
#   CRIME_DESC DESCRIPTION_OF_PAYMENTS  \
# 0        NaN                     NaN
# 1        NaN                     NaN
# 2        NaN                     NaN
# 3        NaN                     NaN
# 4        NaN                     NaN
#
#   DOES_AGREEMENT_DISCUSS_REASONS_OR_RELEVENT_CONSIDERATIONS_FOR_LENIENCY  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   DOJ_CAN_UNILATERALLY_TERMINATE FINE_CALCULATION_INCLUDED FINE_DESCRIPTION  \
# 0                            NaN                       NaN              NaN
# 1                            NaN                       NaN              NaN
# 2                            NaN                       NaN              NaN
# 3                            NaN                       NaN              NaN
# 4                            NaN                       NaN              NaN
#
#   INDEP_MONITOR_REQUIRED MUST_COMPORT_WITH_USSG_OR_AUDIT_COMPLIANCE  \
# 0                    NaN                                        NaN
# 1                    NaN                                        NaN
# 2                    NaN                                        NaN
# 3                    NaN                                        NaN
# 4                    NaN                                        NaN
#
#   OTHER_AGREEMENT OTHER_AGREEMENT_REQUIRED_GOVERNANCE_CHANGES  \
# 0             NaN                                         NaN
# 1             NaN                                         NaN
# 2             NaN                                         NaN
# 3             NaN                                         NaN
# 4             NaN                                         NaN
#
#   OTHER_COMPLIANCE_OFFICER_OR_CONSULTANT_REQUIRED PARALLEL_CIVIL_SUIT  \
# 0                                             NaN                 NaN
# 1                                             NaN                 NaN
# 2                                             NaN                 NaN
# 3                                             NaN                 NaN
# 4                                             NaN                 NaN
#
#   PARALLEL_REGULATORY_ACTION_OR_LOCAL_PROSECUTOR PRE_AGREEMENT_COMPLIANCE  \
# 0                                            NaN                      NaN
# 1                                            NaN                      NaN
# 2                                            NaN                      NaN
# 3                                            NaN                      NaN
# 4                                            NaN                      NaN
#
#   PRE_AGREEMENT_COMPLIANCE_DESCRIPTION PRIVACY_WAIVER  \
# 0                                  NaN            NaN
# 1                                  NaN            NaN
# 2                                  NaN            NaN
# 3                                  NaN            NaN
# 4                                  NaN            NaN
#
#    REGULATORY_DISGORGEMENT_RESTITUTION_FORFEITURE  REGULATORY_FINE REG_AGENCY  \
# 0                                             NaN              NaN        NaN
# 1                                             NaN              NaN        NaN
# 2                                             NaN              NaN        NaN
# 3                                             NaN              NaN        NaN
# 4                                             NaN              NaN        NaN
#
#   STATEMENT_OF_FACTS  TOTAL_REGULATORY UNRELATED_TERMS  AGMT_YEAR SOURCE NOTES
# 0                NaN               NaN             NaN     2003.0  PACER   NaN
# 1                NaN               NaN             NaN     2005.0  PACER   NaN
# 2                NaN               NaN             NaN     2014.0  PACER   NaN
# 3                NaN               NaN             NaN     2006.0  PACER   NaN
# 4                NaN               NaN             NaN     2005.0  PACER   NaN

# %%
df[["FINE", "FORFEITURE_DISGORGEMENT"]].head(2)
# Out:
#       FINE  FORFEITURE_DISGORGEMENT
# 0      0.0                 272734.0
# 1  24000.0                      NaN

# %% [markdown]
# # A little summarizing

# %% [markdown]
# ## How many of cases actually went to trial? How did most of these cases arrive at a decision?

# %%
df
# Out:
#       REC_ID                                 COMPANY DISPOSITION_TYPE  \
# 0        138  1st Union Transfer and Telegraph, Inc.             plea
# 1        139                3D Poultry Loading, Inc.             plea
# 2       2529                         3rd & Bell, LLC             plea
# 3        822                          41 Market Inc.             plea
# 4        140                            45,000, Inc.             plea
# 5        823                         4628 Group Inc.             plea
# 6        824                           70 North, LLC             plea
# 7        825                       806 Trading Corp.             plea
# 8       2530                 83rd & Union Hills, LLC             plea
# 9       2531                        84th & Bell, LLC             plea
# ...      ...                                     ...              ...
# 3028    2516                      ZHU & Partners LLC             plea
# 3029    2711     Zavos Diagnostic Laboratories, Inc.             plea
# 3030    2517                   Zein Automobiles Inc.             plea
# 3031    2923                       Zentner & Zentner             plea
# 3032    2518                          Zeon Chemicals             plea
# 3033    2523                   Zimmer Holdings, Inc.               DP
# 3034     136                      Zuger Kantonalbank               NP
# 3035    3077                     Zwanger-Pesiri Inc.             plea
# 3036     253                             e-gold Ltd.             plea
# 3037    2585                               eAir, LLC             plea
#
#                             PRIMARY_CRIME_CODE SWISS_BANK_PROGRAM  \
# 0                             Money Laundering                NaN
# 1                                  Immigration                NaN
# 2                                  Immigration                NaN
# 3     Controlled substances / Drugs / Meth Act                NaN
# 4                                Environmental                NaN
# 5                                Environmental                NaN
# 6                                Environmental                NaN
# 7                                        Other                NaN
# 8                                  Immigration                NaN
# 9                                  Immigration                NaN
# ...                                        ...                ...
# 3028                               Immigration                NaN
# 3029                                     Other                NaN
# 3030                        Fraud - Accounting                NaN
# 3031                                  Wildlife                NaN
# 3032                                 Antitrust                NaN
# 3033                                 Kickbacks                 No
# 3034                               Fraud - Tax                Yes
# 3035                       Fraud - Health Care                NaN
# 3036                          Money Laundering                NaN
# 3037                             Environmental                NaN
#
#                                                    USAO  \
# 0                           Virginia - Eastern District
# 1                           Arkansas - Western District
# 2                                               Arizona
# 3                           Georgia - Northern District
# 4                           Louisiana - Middle District
# 5                          New York - Northern District
# 6                                                Alaska
# 7                                            New Jersey
# 8                                               Arizona
# 9                                               Arizona
# ...                                                 ...
# 3028                                           Maryland
# 3029                        Kentucky - Eastern District
# 3030                      Washington - Western District
# 3031  USDOJ - Environment & Natural Resources Divisi...
# 3032                         USDOJ - Antitrust Division
# 3033                                         New Jersey
# 3034                               USDOJ - Tax Division
# 3035                        New York - Eastern District
# 3036  District of Columbia,USDOJ - Criminal Division...
# 3037                        Florida - Southern District
#
#                     COUNTRY FINANCIAL_INSTITUTION  \
# 0             United States                   Yes
# 1             United States                    No
# 2             United States                    No
# 3             United States                    No
# 4             United States                    No
# 5             United States                    No
# 6             United States                    No
# 7             United States                    No
# 8             United States                    No
# 9             United States                    No
# ...                     ...                   ...
# 3028          United States                    No
# 3029          United States                    No
# 3030          United States                    No
# 3031          United States                    No
# 3032          United States                    No
# 3033          United States                    No
# 3034            Switzerland                   Yes
# 3035          United States                    No
# 3036  Saint Kitts and Nevis                   Yes
# 3037          United States                    No
#
#                                          CASE_NAME        CASE_ID DOCKET_NO  \
# 0                        USA v. 1st Union Transfer  4:03-cr-00024         8
# 1                        USA v. 3D Poultry Loading  2:04-cr-20061         7
# 2     USA v. Danny's Management Services LLC et al  2:13-cr-01143       510
# 3                            USA v. 41 Market Inc.  4:06-cr-00023        11
# 4                                 USA v. 45000 Inc  3:04-cr-00180        17
# 5                           USA v. 4628 Group Inc.  5:00-cr-00441         8
# 6                              USA v. 70 North LLC  4:13-po-00001       NaN
# 7                   USA v. 806 TRADING CORPORATION  2:11-cr-00579         8
# 8     USA v. Danny's Management Services LLC et al  2:13-cr-01143       512
# 9     USA v. Danny's Management Services LLC et al  2:13-cr-01143       509
# ...                                            ...            ...       ...
# 3028                     USA v. ZHU & Partners LLC  1:08-cr-00261         7
# 3029                                  USA v. Zavos  5:14-cr-00101        33
# 3030                  USA v. Zein Automobiles Inc.  2:13-cr-00319         7
# 3031                USA v. Zentner & Zentner et al  4:00-cr-40218        11
# 3032                    USA v. Zeon Chemicals L.P.  4:05-cr-00017        15
# 3033                                           NaN            NaN       NaN
# 3034                                           NaN            NaN       NaN
# 3035                    USA v. Zwanger-Pesiri Inc.  2:16-cr-00568       NaN
# 3036                      USA v. E-GOLD LTD. et al  1:07-cr-00109       180
# 3037                              USA v. eAIR, LLC  1:14-cr-20392        14
#
#             DATE JUDGMENT_DATE   PLEA_DATE TICKER US_PUBLIC_CO  \
# 0     2003-06-17    2003-06-17  2003-02-28    NaN           No
# 1     2005-01-25    2005-01-25  2004-09-30    NaN           No
# 2     2014-11-21    2014-11-21  2014-11-20    NaN           No
# 3     2006-07-05    2006-07-05  2006-03-16    NaN           No
# 4     2005-06-03    2005-06-03  2004-11-22    NaN           No
# 5     2001-07-31    2001-07-31  2000-09-20    NaN           No
# 6     2013-03-05    2013-03-05         NaN    NaN           No
# 7     2012-03-05    2012-03-05  2011-09-06    NaN           No
# 8     2014-11-24    2014-11-21  2014-11-20    NaN           No
# 9     2014-11-24    2014-11-21  2014-11-20    NaN           No
# ...          ...           ...         ...    ...          ...
# 3028  2008-09-26    2008-09-26  2008-09-26    NaN           No
# 3029  2015-03-23    2015-03-23  2014-09-11    NaN           No
# 3030  2013-10-23    2013-10-23  2013-10-23    NaN           No
# 3031  2000-11-17    2000-11-17  2000-11-16    NaN           No
# 3032  2005-03-17    2005-03-17  2005-03-16    NaN           No
# 3033  2007-09-01           NaN         NaN    NaN          Yes
# 3034  2015-11-06           NaN         NaN    NaN           No
# 3035  2016-11-21    2016-11-21  2016-11-16    NaN           No
# 3036  2008-12-16    2008-12-16  2008-07-18    NaN           No
# 3037  2014-06-20    2014-06-20  2014-06-20    NaN           No
#
#       ADDITIONAL_REGULATORY_FINE_OR_PAYMENT  COMMUNITY_SERVICE_OR_OTHER  \
# 0                                       NaN                         NaN
# 1                                       NaN                         NaN
# 2                                       0.0                         0.0
# 3                                       NaN                         NaN
# 4                                       NaN                         NaN
# 5                                       0.0                         NaN
# 6                                      35.0                         0.0
# 7                                       0.0                         0.0
# 8                                       0.0                         0.0
# 9                                       0.0                         0.0
# ...                                     ...                         ...
# 3028                                    0.0                         0.0
# 3029                                    0.0                         0.0
# 3030                                  400.0                         0.0
# 3031                                    NaN                         NaN
# 3032                                    NaN                         NaN
# 3033                                    0.0                         NaN
# 3034                                    0.0                         0.0
# 3035                                    NaN                         NaN
# 3036                                    NaN                         NaN
# 3037                                    0.0                         NaN
#
#             FINE  FORFEITURE_DISGORGEMENT  PROBATION_LENGTH  RESTITUTION  \
# 0            0.0                 272734.0              12.0          NaN
# 1        24000.0                      NaN              36.0          NaN
# 2           50.0                      0.0               0.0          0.0
# 3        14640.0                      NaN              36.0          NaN
# 4        25000.0                      NaN               0.0       2500.0
# 5       500000.0                      0.0              24.0          0.0
# 6         2000.0                      0.0               0.0          0.0
# 7        42000.0                      0.0               0.0          0.0
# 8           50.0                      0.0               0.0          0.0
# 9           50.0                      0.0               0.0          0.0
# ...          ...                      ...               ...          ...
# 3028     50000.0                      0.0              60.0          0.0
# 3029    250000.0                      0.0               NaN          0.0
# 3030    250000.0                      0.0              24.0          0.0
# 3031         NaN                      NaN               NaN          NaN
# 3032  10500000.0                      NaN               0.0          NaN
# 3033         0.0                      NaN              18.0          NaN
# 3034   3798000.0                      0.0              48.0          0.0
# 3035         0.0                      0.0              24.0          0.0
# 3036    600000.0                1750000.0              36.0          0.0
# 3037    200000.0                      0.0              60.0          0.0
#
#       TOTAL_PAYMENT ACCEPTS_RESPONSIBILITY  \
# 0            272734                    NaN
# 1             24000                    NaN
# 2                50                    NaN
# 3             14640                    NaN
# 4             27500                    NaN
# 5            500000                    NaN
# 6              2000                    NaN
# 7             42000                    NaN
# 8                50                    NaN
# 9                50                    NaN
# ...             ...                    ...
# 3028          50000                    NaN
# 3029         250000                    NaN
# 3030         250000                    NaN
# 3031              0                    NaN
# 3032       10500000                    NaN
# 3033              0                    Yes
# 3034        3798000                    NaN
# 3035              0                    NaN
# 3036        2350000                    NaN
# 3037         200000                    NaN
#
#                        AGREEMENT_REQUIRED_NEW_POSITIONS  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# ...                                                 ...
# 3028                                                NaN
# 3029                                                NaN
# 3030                                                NaN
# 3031                                                NaN
# 3032                                                NaN
# 3033  Yes; Create Compliance Office, headed by Chief...
# 3034                                                NaN
# 3035                                                NaN
# 3036                                                NaN
# 3037                                                NaN
#
#      AGREEMENT_REQUIRED_OUTSIDE_AUDITORS_OR_EXPERTS CITATION_AND_DESCRIPTION  \
# 0                                               NaN                      NaN
# 1                                               NaN                      NaN
# 2                                               NaN                      NaN
# 3                                               NaN                      NaN
# 4                                               NaN                      NaN
# 5                                               NaN                      NaN
# 6                                               NaN                      NaN
# 7                                               NaN                      NaN
# 8                                               NaN                      NaN
# 9                                               NaN                      NaN
# ...                                             ...                      ...
# 3028                                            NaN                      NaN
# 3029                                            NaN                      NaN
# 3030                                            NaN                      NaN
# 3031                                            NaN                      NaN
# 3032                                            NaN                      NaN
# 3033                                             No                      NaN
# 3034                                            NaN                      NaN
# 3035                                            NaN                      NaN
# 3036                                            NaN                      NaN
# 3037                                            NaN                      NaN
#
#      CIVIL_JUDGMENT_OR_SETTLEMENT  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# 5                             NaN
# 6                             NaN
# 7                             NaN
# 8                             NaN
# 9                             NaN
# ...                           ...
# 3028                          NaN
# 3029                          NaN
# 3030                          NaN
# 3031                          NaN
# 3032                          NaN
# 3033                          NaN
# 3034                          NaN
# 3035                          NaN
# 3036                          NaN
# 3037                          NaN
#
#                          COMPLIANCE_PROGRAM_DESCRIPTION  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# ...                                                 ...
# 3028                                                NaN
# 3029                                                NaN
# 3030                                                NaN
# 3031                                                NaN
# 3032                                                NaN
# 3033  Retain monitor to oversee compliance improvements
# 3034                                                NaN
# 3035                                                NaN
# 3036                                                NaN
# 3037                                                NaN
#
#      COMPLIANCE_PROGRAM_REQUIRED_BY_AGREEMENT  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
# ...                                       ...
# 3028                                      NaN
# 3029                                      NaN
# 3030                                      NaN
# 3031                                      NaN
# 3032                                      NaN
# 3033                                      Yes
# 3034                                      NaN
# 3035                                      NaN
# 3036                                      NaN
# 3037                                      NaN
#
#                     COMPLIANCE_REQUIRED_BY_REGULATORS         CRIME_DESC  \
# 0                                                 NaN                NaN
# 1                                                 NaN                NaN
# 2                                                 NaN                NaN
# 3                                                 NaN                NaN
# 4                                                 NaN                NaN
# 5                                                 NaN                NaN
# 6                                                 NaN                NaN
# 7                                                 NaN                NaN
# 8                                                 NaN                NaN
# 9                                                 NaN                NaN
# ...                                               ...                ...
# 3028                                              NaN                NaN
# 3029                                              NaN                NaN
# 3030                                              NaN                NaN
# 3031                                              NaN                NaN
# 3032                                              NaN                NaN
# 3033  Yes; Corporate Integrity Agreement with OIG-HHS  Anti-Kickback Law
# 3034                                              NaN          Tax fraud
# 3035                                              NaN                NaN
# 3036                                              NaN                NaN
# 3037                                              NaN                NaN
#
#      DESCRIPTION_OF_PAYMENTS  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# ...                      ...
# 3028                     NaN
# 3029                     NaN
# 3030                     NaN
# 3031                     NaN
# 3032                     NaN
# 3033                     NaN
# 3034                     NaN
# 3035                     NaN
# 3036                     NaN
# 3037                     NaN
#
#      DOES_AGREEMENT_DISCUSS_REASONS_OR_RELEVENT_CONSIDERATIONS_FOR_LENIENCY  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# ...                                                 ...
# 3028                                                NaN
# 3029                                                NaN
# 3030                                                NaN
# 3031                                                NaN
# 3032                                                NaN
# 3033  Yes; substantial assistance, enhanced complian...
# 3034                                                NaN
# 3035                                                NaN
# 3036                                                NaN
# 3037                                                NaN
#
#      DOJ_CAN_UNILATERALLY_TERMINATE FINE_CALCULATION_INCLUDED  \
# 0                               NaN                       NaN
# 1                               NaN                       NaN
# 2                               NaN                       NaN
# 3                               NaN                       NaN
# 4                               NaN                       NaN
# 5                               NaN                       NaN
# 6                               NaN                       NaN
# 7                               NaN                       NaN
# 8                               NaN                       NaN
# 9                               NaN                       NaN
# ...                             ...                       ...
# 3028                            NaN                       NaN
# 3029                            NaN                       NaN
# 3030                            NaN                       NaN
# 3031                            NaN                       NaN
# 3032                            NaN                       NaN
# 3033                            Yes                        No
# 3034                            NaN                       NaN
# 3035                            NaN                       NaN
# 3036                            NaN                       NaN
# 3037                            NaN                       NaN
#
#      FINE_DESCRIPTION INDEP_MONITOR_REQUIRED  \
# 0                 NaN                    NaN
# 1                 NaN                    NaN
# 2                 NaN                    NaN
# 3                 NaN                    NaN
# 4                 NaN                    NaN
# 5                 NaN                    NaN
# 6                 NaN                    NaN
# 7                 NaN                    NaN
# 8                 NaN                    NaN
# 9                 NaN                    NaN
# ...               ...                    ...
# 3028              NaN                    NaN
# 3029              NaN                    NaN
# 3030              NaN                    NaN
# 3031              NaN                    NaN
# 3032              NaN                    NaN
# 3033             None                    Yes
# 3034              NaN                    NaN
# 3035              NaN                    NaN
# 3036              NaN                    NaN
# 3037              NaN                    NaN
#
#      MUST_COMPORT_WITH_USSG_OR_AUDIT_COMPLIANCE OTHER_AGREEMENT  \
# 0                                           NaN             NaN
# 1                                           NaN             NaN
# 2                                           NaN             NaN
# 3                                           NaN             NaN
# 4                                           NaN             NaN
# 5                                           NaN             NaN
# 6                                           NaN             NaN
# 7                                           NaN             NaN
# 8                                           NaN             NaN
# 9                                           NaN             NaN
# ...                                         ...             ...
# 3028                                        NaN             NaN
# 3029                                        NaN             NaN
# 3030                                        NaN             NaN
# 3031                                        NaN             NaN
# 3032                                        NaN             NaN
# 3033                                         No             NaN
# 3034                                        NaN             NaN
# 3035                                        NaN             NaN
# 3036                                        NaN             NaN
# 3037                                        NaN             NaN
#
#      OTHER_AGREEMENT_REQUIRED_GOVERNANCE_CHANGES  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
# 9                                            NaN
# ...                                          ...
# 3028                                         NaN
# 3029                                         NaN
# 3030                                         NaN
# 3031                                         NaN
# 3032                                         NaN
# 3033                                          No
# 3034                                         NaN
# 3035                                         NaN
# 3036                                         NaN
# 3037                                         NaN
#
#      OTHER_COMPLIANCE_OFFICER_OR_CONSULTANT_REQUIRED PARALLEL_CIVIL_SUIT  \
# 0                                                NaN                 NaN
# 1                                                NaN                 NaN
# 2                                                NaN                 NaN
# 3                                                NaN                 NaN
# 4                                                NaN                 NaN
# 5                                                NaN                 NaN
# 6                                                NaN                 NaN
# 7                                                NaN                 NaN
# 8                                                NaN                 NaN
# 9                                                NaN                 NaN
# ...                                              ...                 ...
# 3028                                             NaN                 NaN
# 3029                                             NaN                 NaN
# 3030                                             NaN                 NaN
# 3031                                             NaN                 NaN
# 3032                                             NaN                 NaN
# 3033                                             Yes                  No
# 3034                                             NaN                 NaN
# 3035                                             NaN                 NaN
# 3036                                             NaN                 NaN
# 3037                                             NaN                 NaN
#
#      PARALLEL_REGULATORY_ACTION_OR_LOCAL_PROSECUTOR PRE_AGREEMENT_COMPLIANCE  \
# 0                                               NaN                      NaN
# 1                                               NaN                      NaN
# 2                                               NaN                      NaN
# 3                                               NaN                      NaN
# 4                                               NaN                      NaN
# 5                                               NaN                      NaN
# 6                                               NaN                      NaN
# 7                                               NaN                      NaN
# 8                                               NaN                      NaN
# 9                                               NaN                      NaN
# ...                                             ...                      ...
# 3028                                            NaN                      NaN
# 3029                                            NaN                      NaN
# 3030                                            NaN                      NaN
# 3031                                            NaN                      NaN
# 3032                                            NaN                      NaN
# 3033                                   Yes; HHS-OIG                      Yes
# 3034                                            NaN                      NaN
# 3035                                            NaN                      NaN
# 3036                                            NaN                      NaN
# 3037                                            NaN                      NaN
#
#                    PRE_AGREEMENT_COMPLIANCE_DESCRIPTION PRIVACY_WAIVER  \
# 0                                                   NaN            NaN
# 1                                                   NaN            NaN
# 2                                                   NaN            NaN
# 3                                                   NaN            NaN
# 4                                                   NaN            NaN
# 5                                                   NaN            NaN
# 6                                                   NaN            NaN
# 7                                                   NaN            NaN
# 8                                                   NaN            NaN
# 9                                                   NaN            NaN
# ...                                                 ...            ...
# 3028                                                NaN            NaN
# 3029                                                NaN            NaN
# 3030                                                NaN            NaN
# 3031                                                NaN            NaN
# 3032                                                NaN            NaN
# 3033  Yes; Appointing Chief Compliance Officer, new ...             No
# 3034                                                NaN            NaN
# 3035                                                NaN            NaN
# 3036                                                NaN            NaN
# 3037                                                NaN            NaN
#
#       REGULATORY_DISGORGEMENT_RESTITUTION_FORFEITURE  REGULATORY_FINE  \
# 0                                                NaN              NaN
# 1                                                NaN              NaN
# 2                                                NaN              NaN
# 3                                                NaN              NaN
# 4                                                NaN              NaN
# 5                                                NaN              NaN
# 6                                                NaN              NaN
# 7                                                NaN              NaN
# 8                                                NaN              NaN
# 9                                                NaN              NaN
# ...                                              ...              ...
# 3028                                             NaN              NaN
# 3029                                             NaN              NaN
# 3030                                             NaN              NaN
# 3031                                             NaN              NaN
# 3032                                             NaN              NaN
# 3033                                             0.0      196500000.0
# 3034                                             NaN              NaN
# 3035                                             NaN              NaN
# 3036                                             NaN              NaN
# 3037                                             NaN              NaN
#
#                                              REG_AGENCY STATEMENT_OF_FACTS  \
# 0                                                   NaN                NaN
# 1                                                   NaN                NaN
# 2                                                   NaN                NaN
# 3                                                   NaN                NaN
# 4                                                   NaN                NaN
# 5                                                   NaN                NaN
# 6                                                   NaN                NaN
# 7                                                   NaN                NaN
# 8                                                   NaN                NaN
# 9                                                   NaN                NaN
# ...                                                 ...                ...
# 3028                                                NaN                NaN
# 3029                                                NaN                NaN
# 3030                                                NaN                NaN
# 3031                                                NaN                NaN
# 3032                                                NaN                NaN
# 3033  Dept. of Health & Human Services; U.S. Postal ...                Yes
# 3034                                                NaN                NaN
# 3035                                                NaN                NaN
# 3036                                                NaN                NaN
# 3037                                                NaN                NaN
#
#       TOTAL_REGULATORY UNRELATED_TERMS  AGMT_YEAR  \
# 0                  NaN             NaN     2003.0
# 1                  NaN             NaN     2005.0
# 2                  NaN             NaN     2014.0
# 3                  NaN             NaN     2006.0
# 4                  NaN             NaN     2005.0
# 5                  NaN             NaN     2001.0
# 6                  NaN             NaN     2013.0
# 7                  NaN             NaN     2012.0
# 8                  NaN             NaN     2014.0
# 9                  NaN             NaN     2014.0
# ...                ...             ...        ...
# 3028               NaN             NaN     2008.0
# 3029               NaN             NaN     2015.0
# 3030               NaN             NaN     2013.0
# 3031               NaN             NaN     2000.0
# 3032               NaN             NaN     2005.0
# 3033       196500000.0              No     2007.0
# 3034               NaN             NaN     2015.0
# 3035               NaN             NaN     2016.0
# 3036               NaN             NaN     2008.0
# 3037               NaN             NaN     2014.0
#
#                                                  SOURCE NOTES
# 0                                                 PACER   NaN
# 1                                                 PACER   NaN
# 2                                                 PACER   NaN
# 3                                                 PACER   NaN
# 4                                                 PACER   NaN
# 5                                                 PACER   NaN
# 6                                                 PACER   NaN
# 7                                                 PACER   NaN
# 8                                                 PACER   NaN
# 9                                                 PACER   NaN
# ...                                                 ...   ...
# 3028                                              PACER   NaN
# 3029                                              PACER   NaN
# 3030                                              PACER   NaN
# 3031                                              PACER   NaN
# 3032                                              PACER   NaN
# 3033                                                NaN   NaN
# 3034  USDOJ - Tax Division - Swiss Bank Program (see...   NaN
# 3035                                              PACER   NaN
# 3036                                              PACER   NaN
# 3037                                              PACER   NaN
#
# [3038 rows x 56 columns]

# %%
df["DISPOSITION_TYPE"].value_counts()
# Out:
# plea               2565
# NP                  266
# DP                  201
# dismissal             2
# declination           2
# trial convicton       2
# Name: DISPOSITION_TYPE, dtype: int64

# %% [markdown]
# ### Graph the previous answer, with the longest bar on top

# %%
df["DISPOSITION_TYPE"].value_counts().sort_values(ascending=True).plot(kind='barh')
#df['state'].value_counts().sort_values(ascending=False).head().plot()

# %% [markdown]
# ## What's the distribution of total payments look like?

# %%
df["TOTAL_PAYMENT"].plot()

# %% [markdown]
# ## Sort by total payments, descending

# %%
df["TOTAL_PAYMENT"].sort_values(ascending=False)
# Out:
# 307     4486800000
# 309     4000000000
# 2913    2800000000
# 1000    2003000000
# 753     1803488986
# 1454    1700000000
# 2167    1300000000
# 1238    1256000000
# 2760    1200000000
# 1168     999999400
#            ...
# 1180             0
# 2666             0
# 1176             0
# 1848             0
# 2124             0
# 2656             0
# 1854             0
# 2653             0
# 1855             0
# 1518             0
# Name: TOTAL_PAYMENT, Length: 3038, dtype: int64

# %% [markdown]
# # Column selection
#
# We wanted to view all of those rows, but honestly that's a little silly. **We can't actually see the data we want!** Let's just select the ones we care about.
#
# ## Create a new dataframe that only includes the company name, disposition type, total payment, and date.

# %%
df.neu = df[["COMPANY", "DISPOSITION_TYPE", "TOTAL_PAYMENT", "DATE"]]
df.neu
# Out:
#                                      COMPANY DISPOSITION_TYPE  TOTAL_PAYMENT  \
# 0     1st Union Transfer and Telegraph, Inc.             plea         272734
# 1                   3D Poultry Loading, Inc.             plea          24000
# 2                            3rd & Bell, LLC             plea             50
# 3                             41 Market Inc.             plea          14640
# 4                               45,000, Inc.             plea          27500
# 5                            4628 Group Inc.             plea         500000
# 6                              70 North, LLC             plea           2000
# 7                          806 Trading Corp.             plea          42000
# 8                    83rd & Union Hills, LLC             plea             50
# 9                           84th & Bell, LLC             plea             50
# ...                                      ...              ...            ...
# 3028                      ZHU & Partners LLC             plea          50000
# 3029     Zavos Diagnostic Laboratories, Inc.             plea         250000
# 3030                   Zein Automobiles Inc.             plea         250000
# 3031                       Zentner & Zentner             plea              0
# 3032                          Zeon Chemicals             plea       10500000
# 3033                   Zimmer Holdings, Inc.               DP              0
# 3034                      Zuger Kantonalbank               NP        3798000
# 3035                     Zwanger-Pesiri Inc.             plea              0
# 3036                             e-gold Ltd.             plea        2350000
# 3037                               eAir, LLC             plea         200000
#
#             DATE
# 0     2003-06-17
# 1     2005-01-25
# 2     2014-11-21
# 3     2006-07-05
# 4     2005-06-03
# 5     2001-07-31
# 6     2013-03-05
# 7     2012-03-05
# 8     2014-11-24
# 9     2014-11-24
# ...          ...
# 3028  2008-09-26
# 3029  2015-03-23
# 3030  2013-10-23
# 3031  2000-11-17
# 3032  2005-03-17
# 3033  2007-09-01
# 3034  2015-11-06
# 3035  2016-11-21
# 3036  2008-12-16
# 3037  2014-06-20
#
# [3038 rows x 4 columns]

# %% [markdown]
# ## Confirm it has 3038 rows and 5 columns

# %%
df.neu.shape
# Out:
# (3038, 4)

# %% [markdown]
# ## Using this subset, extract the year into a separate column called `year`
#
# Your machine will complain. **Let's talk about that error.**

# %%
df.neu.rename(columns={'DATE': 'YEAR'}, inplace=True)
df.neu
# Out:
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py:2746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   **kwargs)
#                                      COMPANY DISPOSITION_TYPE  TOTAL_PAYMENT  \
# 0     1st Union Transfer and Telegraph, Inc.             plea         272734
# 1                   3D Poultry Loading, Inc.             plea          24000
# 2                            3rd & Bell, LLC             plea             50
# 3                             41 Market Inc.             plea          14640
# 4                               45,000, Inc.             plea          27500
# 5                            4628 Group Inc.             plea         500000
# 6                              70 North, LLC             plea           2000
# 7                          806 Trading Corp.             plea          42000
# 8                    83rd & Union Hills, LLC             plea             50
# 9                           84th & Bell, LLC             plea             50
# ...                                      ...              ...            ...
# 3028                      ZHU & Partners LLC             plea          50000
# 3029     Zavos Diagnostic Laboratories, Inc.             plea         250000
# 3030                   Zein Automobiles Inc.             plea         250000
# 3031                       Zentner & Zentner             plea              0
# 3032                          Zeon Chemicals             plea       10500000
# 3033                   Zimmer Holdings, Inc.               DP              0
# 3034                      Zuger Kantonalbank               NP        3798000
# 3035                     Zwanger-Pesiri Inc.             plea              0
# 3036                             e-gold Ltd.             plea        2350000
# 3037                               eAir, LLC             plea         200000
#
#             YEAR
# 0     2003-06-17
# 1     2005-01-25
# 2     2014-11-21
# 3     2006-07-05
# 4     2005-06-03
# 5     2001-07-31
# 6     2013-03-05
# 7     2012-03-05
# 8     2014-11-24
# 9     2014-11-24
# ...          ...
# 3028  2008-09-26
# 3029  2015-03-23
# 3030  2013-10-23
# 3031  2000-11-17
# 3032  2005-03-17
# 3033  2007-09-01
# 3034  2015-11-06
# 3035  2016-11-21
# 3036  2008-12-16
# 3037  2014-06-20
#
# [3038 rows x 4 columns]

# %% [markdown]
# ## Make the 'year' column an integer.
#
# Or at least *try*, then turn it into a float. Why did one work but the other didn't?

# %%
df.neu['YEAR'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-249-edec034ff1b6> in <module>()
# ----> 1 df.neu['YEAR'].astype(int)
#
# /usr/local/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#      89                 else:
#      90                     kwargs[new_arg_name] = new_arg_value
# ---> 91             return func(*args, **kwargs)
#      92         return wrapper
#      93     return _deprecate_kwarg
#
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    3408         # else, only a single dtype is given
#    3409         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 3410                                      **kwargs)
#    3411         return self._constructor(new_data).__finalize__(self)
#    3412
#
# /usr/local/lib/python3.6/site-packages/pandas/core/internals.py in astype(self, dtype, **kwargs)
#    3222
#    3223     def astype(self, dtype, **kwargs):
# -> 3224         return self.apply('astype', dtype=dtype, **kwargs)
#    3225
#    3226     def convert(self, **kwargs):
#
# /usr/local/lib/python3.6/site-packages/pandas/core/internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3089
#    3090             kwargs['mgr'] = self
# -> 3091             applied = getattr(b, f)(**kwargs)
#    3092             result_blocks = _extend_blocks(applied, result_blocks)
#    3093
#
# /usr/local/lib/python3.6/site-packages/pandas/core/internals.py in astype(self, dtype, copy, errors, values, **kwargs)
#     469     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     470         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 471                             **kwargs)
#     472
#     473     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# /usr/local/lib/python3.6/site-packages/pandas/core/internals.py in _astype(self, dtype, copy, errors, values, klass, mgr, **kwargs)
#     519
#     520                 # _astype_nansafe works fine with 1-d only
# --> 521                 values = astype_nansafe(values.ravel(), dtype, copy=True)
#     522                 values = values.reshape(self.shape)
#     523
#
# /usr/local/lib/python3.6/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy)
#     623     elif arr.dtype == np.object_ and np.issubdtype(dtype.type, np.integer):
#     624         # work around NumPy brokenness, #1987
# --> 625         return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     626
#     627     if dtype.name in ("datetime64", "timedelta64"):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe (pandas/_libs/lib.c:16264)()
#
# pandas/_libs/src/util.pxd in util.set_value_at_unsafe (pandas/_libs/lib.c:73298)()
#
# ValueError: invalid literal for int() with base 10: '2003-06-17'

# %% [markdown]
# ## Make a histogram of cases over the years

# %% [markdown]
# ## What was the total amount paid across all cases each year?

# %% [markdown]
# ## Graph it!

# %% [markdown]
# # Cleaning up a column
#
# Take a look at **AGREEMENT_REQUIRED_NEW_POSITIONS** in your **ORIGINAL DATAFRAME**. How many times does it have a value in it?
#
# - Tip: There are a few ways to do this. Maybe you want to ask for an easy one!

# %% [markdown]
# ### What are the top 5 responses for `AGREEMENT_REQUIRED_NEW_POSITIONS`?

# %% [markdown]
# ## That looks messy.
#
# ### HOLD ON, time to learn something
#
# **There are a few ways to do the next question**, but a couple popular methods will have pandas yell at you. You might want to try this new thing called `loc`! **It is used to update a column in a row based on a condition.**
#
# ```
# df.loc[df.country == 'Angola', "continent"] = "Africa"
# ```
#
# This updates the `continent` column to be `Africa` for every row where `df.country == 'Angola'`. You CANNOT do the following, which is probably what you've wanted to do:
#
# ```
# df[df.country == 'Angola']['continent'] = 'Africa'
# ```
#
# And now you know.
#
# ## Start to this up by creating a new column called `required_new_position`.
#
# This column should be `True` if a new position was required, `False` if a new position was not required, and `NaN` if it's unknown.
#
# - Tip: You should use `.str.contains`
# - Tip: Do you know how to say "at the start of a line" using regex?
# - Tip: We've talked about how to avoid `cannot index with vector containing NA / NaN values` but if you get it feel free to write it on the board

# %%
#df.AGREEMENT_REQUIRED_NEW_POSITIONS.str.contains("^No, na=) 
df.AGREEMENT_REQUIRED_NEW_POSITIONS.str.contains("^Yes", na=False)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23       True
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
# 30       True
# 31      False
# 32      False
# 33      False
# 34      False
# 35      False
# 36      False
# 37      False
# 38      False
# 39      False
# 40      False
# 41      False
# 42      False
# 43      False
# 44       True
# 45       True
# 46      False
# 47      False
# 48      False
# 49      False
#         ...
# 2988    False
# 2989    False
# 2990    False
# 2991    False
# 2992    False
# 2993    False
# 2994    False
# 2995    False
# 2996    False
# 2997    False
# 2998    False
# 2999    False
# 3000    False
# 3001    False
# 3002    False
# 3003    False
# 3004    False
# 3005     True
# 3006    False
# 3007    False
# 3008    False
# 3009    False
# 3010    False
# 3011    False
# 3012    False
# 3013    False
# 3014    False
# 3015    False
# 3016    False
# 3017    False
# 3018    False
# 3019    False
# 3020     True
# 3021    False
# 3022    False
# 3023    False
# 3024    False
# 3025    False
# 3026    False
# 3027    False
# 3028    False
# 3029    False
# 3030    False
# 3031    False
# 3032    False
# 3033     True
# 3034    False
# 3035    False
# 3036    False
# 3037    False
# Name: AGREEMENT_REQUIRED_NEW_POSITIONS, Length: 3038, dtype: bool

# %% [markdown]
# ### Confirm that your new column has 163 `True` values and 98 `False` values

# %% [markdown]
# ## Extract the position name into a new column called `new_position`

# %% [markdown]
# ## Make sure you extracted correctly
#
# The line below should show at least SIX rows. If it doesn't show any rows, something went wrong!
#
# - Tip: A `.value_counts()` might look okay, even though something is a little off.

# %%
df[df.new_position == " Compliance Officer"]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-90-ebfe44089f3d> in <module>()
# ----> 1 df[df.new_position == " Compliance Officer"]
#
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'new_position'

# %% [markdown]
# ## Find all cases that required a compliance officer
#
# That one above only gives us six. We want more! **Find at least 23 cases that required the creation of a compliance officer.**
#
# - Tip: Regular expressions might be your friend here
# - Tip: If you get an error about **new_position** not being found, change your code from when you created the column from `df.new_position = ...` to `df['new_position'] = ...`

# %% [markdown]
# ## View the cases that have a compliance officer again.
#
# This time you shouldn't have a `...` in the middle of your dataframe.

# %% [markdown]
# ## What were the most popular crimes that required a compliance officer's appointment?

# %% [markdown]
# # Make a comparison between two groups in the full dataset
#
# For example, "cases before 2003 were likely to be about this, but after 2003 they became about something else."
